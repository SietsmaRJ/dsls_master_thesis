# %%
# Importing some really required stuffs.

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats
import time
from utilities import perform_stats, calc_z_scores

location = 'rjsietsma'

read_loc = '/home/'+location+'/Documents/School/Master_DSLS/Final_Thesis/Initial_Data_exploration/'

imsave_loc = '/home/'+location+'/PycharmProjects/dsls_master_thesis/side_scripts/output_img/'
# FYI: A P-value is the likelyhood that H0 is true.

# %%
# Loading in the first generated train dataset.

data = pd.read_csv("/home/"+location+"/shared/optimal_f1_full_ds_v2.csv", header=0, index_col=0)
data.rename(columns={'default_auc':'AUC'}, inplace=True)
data['Gene'] = data.index
data.head()
# Out:
#               AUC  default_f1  default_recall  default_fpr  default_spec  \
# gene
# RDH12    0.839161    0.833333        0.909091     0.090909      0.909091
# EIF2AK4  0.981481    0.909091        1.000000     0.000000      1.000000
# EIF2AK3  0.966667    0.842105        1.000000     0.000000      1.000000
# PRKAG2   0.981203    0.761905        1.000000     0.000000      1.000000
# JAG1     0.925388    0.928994        0.987421     0.012579      0.987421
#
#          optimal_c  optimal_auc  optimal_f1  optimal_recall  optimal_fpr  \
# gene
# RDH12        0.020     0.839161    0.833333        0.909091     0.090909
# EIF2AK4      0.020     0.981481    0.909091        1.000000     0.000000
# EIF2AK3      0.020     0.966667    0.842105        1.000000     0.000000
# PRKAG2       0.020     0.981203    0.761905        1.000000     0.000000
# JAG1         0.025     0.937810    0.940120        0.987421     0.012579
#
#          optimal_spec  n_tot  n_benign  n_malign     Gene
# gene
# RDH12        0.909091     24        13        11    RDH12
# EIF2AK4      1.000000     32        27         5  EIF2AK4
# EIF2AK3      1.000000     53        45         8  EIF2AK3
# PRKAG2       1.000000    282       266        16   PRKAG2
# JAG1         0.987421    320       161       159     JAG1

# %%
# Some sorting and first impressions of the data.

data.sort_values(by=['AUC'], ascending=True)

data = data.drop(data[data['Gene'].isna()].index)


data['b/p ratio'] = data['n_benign'] / data['n_malign']
data_with_auc = data[data['AUC'].notnull()]
data_with_auc[data_with_auc['n_malign'] != 0].sort_values(by=['b/p ratio'], ascending=False)
# Out:
#              AUC  default_f1  default_recall  default_fpr  default_spec  \
# gene
# AKAP9   0.969530    0.031746        1.000000     0.000000      1.000000
# CELSR2  0.998885    0.500000        1.000000     0.000000      1.000000
# KIF1B   0.988848    0.100000        1.000000     0.000000      1.000000
# GIGYF2  0.482484    0.000000        0.000000     1.000000      0.000000
# NRXN3   0.488735    0.000000        0.000000     1.000000      0.000000
# ...          ...         ...             ...          ...           ...
# ZBTB18  0.726190    0.930233        0.952381     0.047619      0.952381
# DDX3X   0.789016    0.960396        0.989796     0.010204      0.989796
# GJB1    0.884454    0.869359        0.768908     0.231092      0.768908
# FBXL4   0.982759    0.982456        0.965517     0.034483      0.965517
# AVP     0.970588    0.969697        0.941176     0.058824      0.941176
#
#         optimal_c  optimal_auc  optimal_f1  optimal_recall  optimal_fpr  \
# gene
# AKAP9       0.044     0.987512    0.074074        1.000000     0.000000
# CELSR2      0.023     0.999443    0.666667        1.000000     0.000000
# KIF1B       0.026     0.992565    0.142857        1.000000     0.000000
# GIGYF2      0.020     0.482484    0.000000        0.000000     1.000000
# NRXN3       0.020     0.488735    0.000000        0.000000     1.000000
# ...           ...          ...         ...             ...          ...
# ZBTB18      0.020     0.726190    0.930233        0.952381     0.047619
# DDX3X       0.023     0.818427    0.965174        0.989796     0.010204
# GJB1        0.001     0.916285    0.968017        0.760504     0.239496
# FBXL4       0.012     1.000000    1.000000        0.965517     0.034483
# AVP         0.020     0.970588    0.969697        0.941176     0.058824
#
#         optimal_spec  n_tot  n_benign  n_malign    Gene    b/p ratio
# gene
# AKAP9       1.000000   1002      1001         1   AKAP9  1001.000000
# CELSR2      1.000000    898       897         1  CELSR2   897.000000
# KIF1B       1.000000    808       807         1   KIF1B   807.000000
# GIGYF2      0.000000    629       628         1  GIGYF2   628.000000
# NRXN3       0.000000    578       577         1   NRXN3   577.000000
# ...              ...    ...       ...       ...     ...          ...
# ZBTB18      0.952381     25         4        21  ZBTB18     0.190476
# DDX3X       0.989796    115        17        98   DDX3X     0.173469
# GJB1        0.760504    271        33       238    GJB1     0.138655
# FBXL4       0.965517     65         7        58   FBXL4     0.120690
# AVP         0.941176     19         2        17     AVP     0.117647
#
# [2807 rows x 16 columns]

# %%
# Plotting of benign/pathogenic ratio and AUC.

sorted_datawithauc = data_with_auc[data_with_auc['n_malign'] != 0].sort_values(by=['b/p ratio'], ascending=False)
sorted_datawithauc.index = np.arange(sorted_datawithauc.shape[0])
fig = plt.figure(figsize=(15,10))
axes = fig.add_axes([0.1,0.1,0.8,0.8])\

sorted_datawithauc_zscores = calc_z_scores(np.array(sorted_datawithauc[["AUC",'b/p ratio']]))

axes.plot(sorted_datawithauc.index, sorted_datawithauc_zscores[:,0], c='red', label='auc')
axes.plot(sorted_datawithauc.index, sorted_datawithauc_zscores[:,1], c='blue', label='bp ratio')
# axes.plot(sorted_datawithauc.index, sorted_datawithauc['capice'], c='yellow', label='capice')
axes.set_xlabel("Gene")
axes.set_ylabel("Score")
axes.set_title("CAPICE score vs AUC")
axes.legend()
plt.show()

perform_stats(sorted_datawithauc_zscores[:,0], sorted_datawithauc_zscores[:,1])
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 1.120786578409249e-278
# The Wilcoxon test p-value: 2.2055203579089494e-49
# The Pearson correlation: -0.09606336271471676,
# p-value: 3.413183494601378e-07

# %%
# Get an overview of the genes that do not have multiple categories (pathogenic and malignant)
# but that do have malignant and benign samples. Interestingly, no AUC could be calculated.
datanomcat = data[data['m_cat'] == 0]

datanomcat.sort_values(by=['AUC'], ascending=True)

list_of_odd_genes = []

for row in datanomcat['Gene'].unique():
    if isinstance(row, str):
        n_benign = datanomcat[datanomcat['Gene'] == row]['N_benign'].item()
        n_malign = datanomcat[datanomcat['Gene'] == row]['N_malign'].item()
        auc = datanomcat[datanomcat['Gene'] == row]['AUC'].item()
        if n_benign != 0 and n_malign != 0:
            print(f'Gene {row} does have benign: {n_benign} and malignant: {n_malign} samples, \n'
                 f'AUC of gene {row} = {auc}. \n')
            list_of_odd_genes.append(row)
    else:
        print(f'Encountered not a gene!: {row}')
# Out:
# Gene TCF20 does have benign: 2 and malignant: 6 samples,
# AUC of gene TCF20 = nan.
#
# Gene GMNN does have benign: 3 and malignant: 3 samples,
# AUC of gene GMNN = nan.
#
# Gene SLC6A9 does have benign: 2 and malignant: 2 samples,
# AUC of gene SLC6A9 = nan.
#
# Gene MRPS34 does have benign: 1 and malignant: 2 samples,
# AUC of gene MRPS34 = nan.
#
# Gene RAB11B does have benign: 2 and malignant: 2 samples,
# AUC of gene RAB11B = nan.
#
# Gene RBP3 does have benign: 26 and malignant: 1 samples,
# AUC of gene RBP3 = nan.
#
# Gene HPS6 does have benign: 16 and malignant: 1 samples,
# AUC of gene HPS6 = nan.
#
# Gene TMPRSS6 does have benign: 14 and malignant: 1 samples,
# AUC of gene TMPRSS6 = nan.
#
# Gene CEACAM16 does have benign: 215 and malignant: 1 samples,
# AUC of gene CEACAM16 = nan.
#
# Gene SLC25A3 does have benign: 7 and malignant: 1 samples,
# AUC of gene SLC25A3 = nan.
#
# Gene IL1RN does have benign: 18 and malignant: 1 samples,
# AUC of gene IL1RN = nan.
#
# Gene GRID2 does have benign: 5 and malignant: 1 samples,
# AUC of gene GRID2 = nan.
#
# Gene NLRP1 does have benign: 14 and malignant: 1 samples,
# AUC of gene NLRP1 = nan.
#
# Gene LIPE does have benign: 2 and malignant: 1 samples,
# AUC of gene LIPE = nan.
#
# Gene NDUFA1 does have benign: 11 and malignant: 1 samples,
# AUC of gene NDUFA1 = nan.

# %%
# Dropping entries that have no gene, sorting on the number of malignant samples.
datanomcat = datanomcat.drop(datanomcat[datanomcat['Gene'].isna()].index)
datanomcat.sort_values(by=['N_malign'],ascending=True)
# Out:
#          Gene  AUC  FPR  Precision  Recall/TPR  F-score  N_benign  N_malign  \
# 5958    CIDEB  NaN  NaN        NaN         NaN      NaN         3         0
# 7186  TRAPPC4  NaN  NaN        NaN         NaN      NaN         5         0
# 7185    PSMD8  NaN  NaN        NaN         NaN      NaN         1         0
# 7184    KDM4E  NaN  NaN        NaN         NaN      NaN         1         0
# 7183   WBP2NL  NaN  NaN        NaN         NaN      NaN         7         0
# ...       ...  ...  ...        ...         ...      ...       ...       ...
# 219    DNAAF5  NaN  NaN        NaN         NaN      NaN         0         5
# 629     TCF20  NaN  NaN        NaN         NaN      NaN         2         6
# 941      P3H1  NaN  NaN        NaN         NaN      NaN         0         9
# 446    ADGRG1  NaN  NaN        NaN         NaN      NaN         0        17
# 139    ADGRV1  NaN  NaN        NaN         NaN      NaN         0        36
#
#       m_cat  n_snvs  b/p ratio
# 5958      0       3        inf
# 7186      0       5        inf
# 7185      0       1        inf
# 7184      0       1        inf
# 7183      0       7        inf
# ...     ...     ...        ...
# 219       0       5   0.000000
# 629       0       8   0.333333
# 941       0       9   0.000000
# 446       0      17   0.000000
# 139       0      36   0.000000
#
# [7330 rows x 11 columns]

# %%
# Sorting but now on the number of benign samples.
datanomcat.sort_values(by=['N_benign'], ascending=False)
# Out:
#           Gene  AUC  FPR  Precision  Recall/TPR  F-score  N_benign  N_malign  \
# 2225   MIR548N  NaN  NaN        NaN         NaN      NaN     10289         0
# 2140  MIR548AZ  NaN  NaN        NaN         NaN      NaN      8781         0
# 2329  MIR1268A  NaN  NaN        NaN         NaN      NaN      7648         0
# 2610     MYHAS  NaN  NaN        NaN         NaN      NaN      6946         0
# 2093  MIR1273H  NaN  NaN        NaN         NaN      NaN      4103         0
# ...        ...  ...  ...        ...         ...      ...       ...       ...
# 1759     PIBF1  NaN  NaN        NaN         NaN      NaN         0         2
# 1751     VAC14  NaN  NaN        NaN         NaN      NaN         0         1
# 1728   SLC27A4  NaN  NaN        NaN         NaN      NaN         0         1
# 1709     WARS2  NaN  NaN        NaN         NaN      NaN         0         2
# 139     ADGRV1  NaN  NaN        NaN         NaN      NaN         0        36
#
#       m_cat  n_snvs  b/p ratio
# 2225      0   10289        inf
# 2140      0    8781        inf
# 2329      0    7648        inf
# 2610      0    6946        inf
# 2093      0    4103        inf
# ...     ...     ...        ...
# 1759      0       2        0.0
# 1751      0       1        0.0
# 1728      0       1        0.0
# 1709      0       2        0.0
# 139       0      36        0.0
#
# [7330 rows x 11 columns]

# %%
# Reversed number of malignant sorting.
datanomcat.sort_values(by=['N_malign'], ascending=False)
# Out:
#         Gene  AUC  FPR  Precision  Recall/TPR  F-score  N_benign  N_malign  \
# 139   ADGRV1  NaN  NaN        NaN         NaN      NaN         0        36
# 446   ADGRG1  NaN  NaN        NaN         NaN      NaN         0        17
# 941     P3H1  NaN  NaN        NaN         NaN      NaN         0         9
# 629    TCF20  NaN  NaN        NaN         NaN      NaN         2         6
# 219   DNAAF5  NaN  NaN        NaN         NaN      NaN         0         5
# ...      ...  ...  ...        ...         ...      ...       ...       ...
# 4779  RB1CC1  NaN  NaN        NaN         NaN      NaN         3         0
# 4778    NOL4  NaN  NaN        NaN         NaN      NaN         1         0
# 4777   MKI67  NaN  NaN        NaN         NaN      NaN         7         0
# 4776  ZNF365  NaN  NaN        NaN         NaN      NaN         2         0
# 9623    COQ5  NaN  NaN        NaN         NaN      NaN         1         0
#
#       m_cat  n_snvs  b/p ratio
# 139       0      36   0.000000
# 446       0      17   0.000000
# 941       0       9   0.000000
# 629       0       8   0.333333
# 219       0       5   0.000000
# ...     ...     ...        ...
# 4779      0       3        inf
# 4778      0       1        inf
# 4777      0       7        inf
# 4776      0       2        inf
# 9623      0       1        inf
#
# [7330 rows x 11 columns]

# %%
# Creating and applying filter to find it back on https://molgenis26.gcc.rug.nl/downloads/capice/plots/
usable = data[data['m_cat'] == 1]
filter1 = usable["N_benign"] > 5
filter2 = usable['N_malign'] > 5
m_cat_filtered_usable = usable.where(filter1 & filter2).dropna()
m_cat_filtered_usable.sort_values(by=['AUC'], ascending=True)
# Out:
#         Gene       AUC       FPR  Precision  Recall/TPR   F-score  N_benign  \
# 792    ANOS1  0.642857  0.000000   0.750000    1.000000  0.857143       7.0
# 1168   ARID2  0.652174  0.000000   0.448276    1.000000  0.619048      23.0
# 459     EBF3  0.666667  0.000000   0.703704    1.000000  0.826087      12.0
# 1373    RPL5  0.669643  0.285714   0.625000    0.714286  0.666667       8.0
# 22     DDX3X  0.700000  0.000000   0.913043    1.000000  0.954545      10.0
# ...      ...       ...       ...        ...         ...       ...       ...
# 393     HMBS  1.000000  0.000000   1.000000    1.000000  1.000000      21.0
# 1409  GUCY2D  1.000000  0.000000   1.000000    1.000000  1.000000      35.0
# 285      XPA  1.000000  0.000000   1.000000    1.000000  1.000000       7.0
# 1100   ALDOB  1.000000  0.000000   1.000000    1.000000  1.000000      16.0
# 604     MMAB  1.000000  0.000000   1.000000    1.000000  1.000000      47.0
#
#       N_malign  m_cat  n_snvs  b/p ratio
# 792       15.0    1.0    22.0   0.466667
# 1168      13.0    1.0    36.0   1.769231
# 459       19.0    1.0    31.0   0.631579
# 1373       7.0    1.0    15.0   1.142857
# 22        63.0    1.0    73.0   0.158730
# ...        ...    ...     ...        ...
# 393       14.0    1.0    35.0   1.500000
# 1409      10.0    1.0    45.0   3.500000
# 285        6.0    1.0    13.0   1.166667
# 1100      16.0    1.0    32.0   1.000000
# 604        7.0    1.0    54.0   6.714286
#
# [989 rows x 11 columns]

# %%
# Filtering out the entries that do not have an AUC. (there's an easier way to do this)
filter_auc_nan = data['AUC'].isna()
new_data = data.where(~filter_auc_nan).dropna()
new_data.sort_values(by=['n_tot'], ascending=False)
# Out:
#                AUC  default_f1  default_recall  default_fpr  default_spec  \
# gene
# TTN       0.940371    0.762632        0.975814     0.024186      0.975814
# BRCA2     0.948638    0.965444        0.998541     0.001459      0.998541
# BRCA1     0.948371    0.970153        0.996820     0.003180      0.996820
# NF1       0.915487    0.951411        0.988063     0.011937      0.988063
# RYR2      0.897235    0.608955        0.842975     0.157025      0.842975
# ...            ...         ...             ...          ...           ...
# PCGF2     1.000000    1.000000        1.000000     0.000000      1.000000
# ATP6V1E1  1.000000    1.000000        1.000000     0.000000      1.000000
# NDNL2     0.000000    0.000000        0.000000     1.000000      0.000000
# DNAJC19   1.000000    1.000000        1.000000     0.000000      1.000000
# NUP37     1.000000    1.000000        1.000000     0.000000      1.000000
#
#           optimal_c  optimal_auc  optimal_f1  optimal_recall  optimal_fpr  \
# gene
# TTN           0.065     0.939890    0.827415        0.930233     0.069767
# BRCA2         0.041     0.971743    0.980469        0.997812     0.002188
# BRCA1         0.038     0.964726    0.979008        0.995911     0.004089
# NF1           0.035     0.942036    0.965261        0.987520     0.012480
# RYR2          0.040     0.895214    0.742424        0.809917     0.190083
# ...             ...          ...         ...             ...          ...
# PCGF2         0.020     1.000000    1.000000        0.000000     1.000000
# ATP6V1E1      0.020     1.000000    1.000000        1.000000     0.000000
# NDNL2         0.020     0.000000    0.000000        0.000000     1.000000
# DNAJC19       0.020     1.000000    1.000000        1.000000     0.000000
# NUP37         0.020     1.000000    1.000000        1.000000     0.000000
#
#           optimal_spec  n_tot  n_benign  n_malign      Gene  b/p ratio
# gene
# TTN           0.930233   7670      6595      1075       TTN   6.134884
# BRCA2         0.997812   4638      1896      2742     BRCA2   0.691466
# BRCA1         0.995911   3480      1279      2201     BRCA1   0.581100
# NF1           0.987520   2887      1044      1843       NF1   0.566468
# RYR2          0.809917   2430      2309       121      RYR2  19.082645
# ...                ...    ...       ...       ...       ...        ...
# PCGF2         0.000000      2         1         1     PCGF2   1.000000
# ATP6V1E1      1.000000      2         1         1  ATP6V1E1   1.000000
# NDNL2         0.000000      2         1         1     NDNL2   1.000000
# DNAJC19       1.000000      2         1         1   DNAJC19   1.000000
# NUP37         1.000000      2         1         1     NUP37   1.000000
#
# [2807 rows x 16 columns]

# %%
# Creating a new copy of the dataset for log transformation of the number of samples.
# Also a sigmoid function just in case.
new_data_log_transformed = new_data.copy()

def sigmoid(x):
    return 1/(1+np.exp(-x))

total_snvs = new_data_log_transformed['n_tot'].sum()
total_benign = new_data_log_transformed['n_benign'].sum()
total_malign = new_data_log_transformed['n_malign'].sum()

# *100 just for scaling
new_data_log_transformed['n_tot'] = new_data_log_transformed['n_tot'].apply(lambda x: x/total_snvs*100)
new_data_log_transformed['n_benign'] = new_data_log_transformed['n_benign'].apply(lambda x: x/total_benign*100)
new_data_log_transformed['n_malign'] = new_data_log_transformed['n_malign'].apply(lambda x: x/total_malign*100)

new_data_log_transformed.sort_values(by=['n_tot'], ascending=False)
# Out:
#                AUC  default_f1  default_recall  default_fpr  default_spec  \
# gene
# TTN       0.940371    0.762632        0.975814     0.024186      0.975814
# BRCA2     0.948638    0.965444        0.998541     0.001459      0.998541
# BRCA1     0.948371    0.970153        0.996820     0.003180      0.996820
# NF1       0.915487    0.951411        0.988063     0.011937      0.988063
# RYR2      0.897235    0.608955        0.842975     0.157025      0.842975
# ...            ...         ...             ...          ...           ...
# PCGF2     1.000000    1.000000        1.000000     0.000000      1.000000
# ATP6V1E1  1.000000    1.000000        1.000000     0.000000      1.000000
# NDNL2     0.000000    0.000000        0.000000     1.000000      0.000000
# DNAJC19   1.000000    1.000000        1.000000     0.000000      1.000000
# NUP37     1.000000    1.000000        1.000000     0.000000      1.000000
#
#           optimal_c  optimal_auc  optimal_f1  optimal_recall  optimal_fpr  \
# gene
# TTN           0.065     0.939890    0.827415        0.930233     0.069767
# BRCA2         0.041     0.971743    0.980469        0.997812     0.002188
# BRCA1         0.038     0.964726    0.979008        0.995911     0.004089
# NF1           0.035     0.942036    0.965261        0.987520     0.012480
# RYR2          0.040     0.895214    0.742424        0.809917     0.190083
# ...             ...          ...         ...             ...          ...
# PCGF2         0.020     1.000000    1.000000        0.000000     1.000000
# ATP6V1E1      0.020     1.000000    1.000000        1.000000     0.000000
# NDNL2         0.020     0.000000    0.000000        0.000000     1.000000
# DNAJC19       0.020     1.000000    1.000000        1.000000     0.000000
# NUP37         0.020     1.000000    1.000000        1.000000     0.000000
#
#           optimal_spec     n_tot  n_benign  n_malign      Gene  b/p ratio
# gene
# TTN           0.930233  2.523765  2.746726  1.684768       TTN   6.134884
# BRCA2         0.997812  1.526105  0.789658  4.297334     BRCA2   0.691466
# BRCA1         0.995911  1.145072  0.532686  3.449465     BRCA1   0.581100
# NF1           0.987520  0.949949  0.434812  2.888398       NF1   0.566468
# RYR2          0.809917  0.799576  0.961667  0.189634      RYR2  19.082645
# ...                ...       ...       ...       ...       ...        ...
# PCGF2         0.000000  0.000658  0.000416  0.001567     PCGF2   1.000000
# ATP6V1E1      1.000000  0.000658  0.000416  0.001567  ATP6V1E1   1.000000
# NDNL2         0.000000  0.000658  0.000416  0.001567     NDNL2   1.000000
# DNAJC19       1.000000  0.000658  0.000416  0.001567   DNAJC19   1.000000
# NUP37         1.000000  0.000658  0.000416  0.001567     NUP37   1.000000
#
# [2807 rows x 16 columns]

# %% [markdown]
# # Log transformed number of datapoints

# %%
temp_data = new_data_log_transformed[['AUC', 'n_tot']]
temp_data = temp_data.sort_values(by=['n_tot'], ascending=False)
temp_data.index = np.arange(temp_data.shape[0])
temp_data.plot(figsize=(20,10))
plt.show()

perform_stats(temp_data['AUC'], temp_data['n_tot'])
# Due to this plot, I see that there's not really a corrrelation in the number of snvs and the AUC
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 0.0
# The Wilcoxon test p-value: 0.0
# The Pearson correlation: -0.01903078532892713,
# p-value: 0.31349542952568876

# %%
temp_data = new_data_log_transformed[['AUC', 'n_benign']]
temp_data = temp_data.sort_values(by=['n_benign'], ascending=False)
temp_data.index = np.arange(temp_data.shape[0])
temp_data.plot(figsize=(20,10))
plt.show()

perform_stats(temp_data['AUC'], temp_data['n_benign'])

# Some more fluctiations, but still at the end it seems to be somewhat of a correlation.

# //TODO: add ratio pathogenic vs benign
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 0.0
# The Wilcoxon test p-value: 0.0
# The Pearson correlation: -0.04088086138665305,
# p-value: 0.03032228011879772

# %%
temp_data = new_data_log_transformed[['AUC', 'n_malign']]
temp_data = temp_data.sort_values(by=['n_malign'], ascending=False)
temp_data.index = np.arange(temp_data.shape[0])
temp_data.plot(figsize=(20,10))
plt.show()

perform_stats(temp_data['AUC'], temp_data['n_malign'])

# More stable, especially in the first 1000 genes
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 0.0
# The Wilcoxon test p-value: 0.0
# The Pearson correlation: 0.030832263488195146,
# p-value: 0.10242929595346843

# %% [markdown]
# # Z-scores

# %%
temp_data = calc_z_scores(np.array(new_data[['AUC', 'n_tot']].sort_values(by=['n_tot'], ascending=False)))
indexing = np.arange(new_data.shape[0])
fig = plt.figure(figsize=(15,10))
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(indexing, temp_data[:,0], c='red', label='AUC')
axes.plot(indexing, temp_data[:,1], c='blue', label='n_tot')
axes.set_xlabel("Genes")
axes.set_ylabel("Z score")
axes.set_title("AUC & N_SNVS Z-scores")
axes.legend()
plt.show()


perform_stats(temp_data[:,0],temp_data[:,1])
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 1.5010903625240218e-240
# The Wilcoxon test p-value: 4.8916738948011776e-30
# The Pearson correlation: -0.01903078532892713,
# p-value: 0.31349542952568876

# %%
temp_data = calc_z_scores(np.array(new_data[['AUC', 'n_benign']].sort_values(by=['n_benign'], ascending=False)))
indexing = np.arange(new_data.shape[0])
fig = plt.figure(figsize=(15,10))
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(indexing, temp_data[:,0], c='red', label='AUC')
axes.plot(indexing, temp_data[:,1], c='blue', label='N_benign')
axes.set_xlabel("Genes")
axes.set_ylabel("Z score")
axes.set_title("AUC & N_benign Z-scores")
axes.legend()
plt.show()


perform_stats(temp_data[:,0],temp_data[:,1])
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 4.239196973666013e-234
# The Wilcoxon test p-value: 3.554845640246e-31
# The Pearson correlation: -0.04088086138665305,
# p-value: 0.03032228011879772

# %%
temp_data = calc_z_scores(np.array(new_data[['AUC', 'n_malign']].sort_values(by=['n_malign'], ascending=False)))
indexing = np.arange(new_data.shape[0])
fig = plt.figure(figsize=(15,10))
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(indexing, temp_data[:,0], c='red', label='AUC')
axes.plot(indexing, temp_data[:,1], c='blue', label='N_Malignant')
axes.set_xlabel("Genes")
axes.set_ylabel("Z score")
axes.set_title("AUC & N_Malignant Z-scores")
axes.legend()
plt.show()


perform_stats(temp_data[:,0],temp_data[:,1])
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 0.0
# The Wilcoxon test p-value: 1.0333765359528123e-32
# The Pearson correlation: 0.03083226348819515,
# p-value: 0.10242929595346843

# %%
# (not) enough snvs = (n)es
n_genes_nes = data['AUC'].isna().sum()
n_genes_es = data['AUC'].dropna().count()
print(f'Amount of genes that have enough SNVs for an AUC: {n_genes_es}, \n'
     f'amount of genes that do not have enough SNVs: {n_genes_nes}.')
# Out:
# Amount of genes that have enough SNVs for an AUC: 2292,
# amount of genes that do not have enough SNVs: 7330.

# %%
# Loading in new dataset containing the AUC for each gene per SNV
auc_snv_data = pd.read_csv("/home/"+location+"/Documents/School/Master_DSLS/Final_Thesis/Initial_Data_exploration/test_results_genes_auc.csv", header=0, index_col=0)
auc_snv_data.head()
# Out:
#   #Chrom       Pos Ref Alt    max_AF     Consequence label  revel  clinpred  \
# 0     21  33974174   C   G  0.000058       STOP_LOST  LB/B    NaN       NaN
# 1     21  33974278   C  CA  0.000045     FRAME_SHIFT  LB/B    NaN       NaN
# 2      X  99661625   G   C  0.000037      SYNONYMOUS  LB/B    NaN       NaN
# 3      X  99663098   G  GT  0.000013     STOP_GAINED  LB/B    NaN       NaN
# 4      X  99662275   C   G  0.000212  NON_SYNONYMOUS  LB/B  0.527       NaN
#
#    sift  provean   PHRED  fathmm_score    capice  ponp2      gene       auc
# 0   NaN      NaN  15.050           NaN  0.003275    NaN  C21orf59       NaN
# 1   NaN      NaN  35.000           NaN  0.304741    NaN  C21orf59       NaN
# 2  0.00    -0.00   0.806           NaN  0.000075    NaN    PCDH19  0.906593
# 3   NaN      NaN  35.000           NaN  0.998694    NaN    PCDH19  0.906593
# 4  0.95     2.51  27.000           NaN  0.863940  0.436    PCDH19  0.906593

# %%
# Get only the snvs of the genes that have an AUC
auc_full_data = auc_snv_data[~auc_snv_data['auc'].isna()]
auc_full_data
# Out:
#       #Chrom       Pos Ref     Alt    max_AF       Consequence label  revel  \
# 2          X  99661625   G       C  0.000037        SYNONYMOUS  LB/B    NaN
# 3          X  99663098   G      GT  0.000013       STOP_GAINED  LB/B    NaN
# 4          X  99662275   C       G  0.000212    NON_SYNONYMOUS  LB/B  0.527
# 5          X  99657670   A  ACCCAG  0.000000       FRAME_SHIFT  LP/P    NaN
# 6         17  29509638   C       T  0.000000        SYNONYMOUS  LB/B    NaN
# ...      ...       ...  ..     ...       ...               ...   ...    ...
# 10539      X  19368150   A    AAGA  0.000000           INFRAME  LP/P    NaN
# 10541      2  31754497   T       C  0.000033  NONCODING_CHANGE  LP/P    NaN
# 10542      2  31754393   C       T  0.000000  NONCODING_CHANGE  LP/P    NaN
# 10543      2  31758741   T       C  0.000200  NONCODING_CHANGE  LP/P    NaN
# 10544     16    223597   T       C  0.001252         STOP_LOST  LP/P    NaN
#
#        clinpred   sift  provean   PHRED  fathmm_score    capice  ponp2  \
# 2           NaN  0.000    -0.00   0.806           NaN  0.000075    NaN
# 3           NaN    NaN      NaN  35.000           NaN  0.998694    NaN
# 4           NaN  0.950     2.51  27.000           NaN  0.863940  0.436
# 5           NaN    NaN      NaN  35.000           NaN  0.687628    NaN
# 6           NaN  0.647    -0.00  10.760           NaN  0.001511    NaN
# ...         ...    ...      ...     ...           ...       ...    ...
# 10539       NaN    NaN     8.92  19.510           NaN  0.121208    NaN
# 10541       NaN    NaN      NaN  19.790      0.951270  0.918898    NaN
# 10542       NaN    NaN      NaN  21.700           NaN  0.985064    NaN
# 10543       NaN    NaN      NaN  20.800      0.912937  0.474717    NaN
# 10544       NaN    NaN      NaN  18.020           NaN  0.971616    NaN
#
#          gene       auc
# 2      PCDH19  0.906593
# 3      PCDH19  0.906593
# 4      PCDH19  0.906593
# 5      PCDH19  0.906593
# 6         NF1  0.922413
# ...       ...       ...
# 10539   PDHA1  0.894737
# 10541  SRD5A2  0.921053
# 10542  SRD5A2  0.921053
# 10543  SRD5A2  0.921053
# 10544    HBA2  0.937500
#
# [8946 rows x 17 columns]

# %%
# Label replacement
auc_full_data['label'] = auc_full_data['label'].replace({'LB/B':0,'LP/P':1})
auc_full_data
# Out:
# <ipython-input-19-8a86bb65a478>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   auc_full_data['label'] = auc_full_data['label'].replace({'LB/B':0,'LP/P':1})
#       #Chrom       Pos Ref     Alt    max_AF       Consequence  label  revel  \
# 2          X  99661625   G       C  0.000037        SYNONYMOUS      0    NaN
# 3          X  99663098   G      GT  0.000013       STOP_GAINED      0    NaN
# 4          X  99662275   C       G  0.000212    NON_SYNONYMOUS      0  0.527
# 5          X  99657670   A  ACCCAG  0.000000       FRAME_SHIFT      1    NaN
# 6         17  29509638   C       T  0.000000        SYNONYMOUS      0    NaN
# ...      ...       ...  ..     ...       ...               ...    ...    ...
# 10539      X  19368150   A    AAGA  0.000000           INFRAME      1    NaN
# 10541      2  31754497   T       C  0.000033  NONCODING_CHANGE      1    NaN
# 10542      2  31754393   C       T  0.000000  NONCODING_CHANGE      1    NaN
# 10543      2  31758741   T       C  0.000200  NONCODING_CHANGE      1    NaN
# 10544     16    223597   T       C  0.001252         STOP_LOST      1    NaN
#
#        clinpred   sift  provean   PHRED  fathmm_score    capice  ponp2  \
# 2           NaN  0.000    -0.00   0.806           NaN  0.000075    NaN
# 3           NaN    NaN      NaN  35.000           NaN  0.998694    NaN
# 4           NaN  0.950     2.51  27.000           NaN  0.863940  0.436
# 5           NaN    NaN      NaN  35.000           NaN  0.687628    NaN
# 6           NaN  0.647    -0.00  10.760           NaN  0.001511    NaN
# ...         ...    ...      ...     ...           ...       ...    ...
# 10539       NaN    NaN     8.92  19.510           NaN  0.121208    NaN
# 10541       NaN    NaN      NaN  19.790      0.951270  0.918898    NaN
# 10542       NaN    NaN      NaN  21.700           NaN  0.985064    NaN
# 10543       NaN    NaN      NaN  20.800      0.912937  0.474717    NaN
# 10544       NaN    NaN      NaN  18.020           NaN  0.971616    NaN
#
#          gene       auc
# 2      PCDH19  0.906593
# 3      PCDH19  0.906593
# 4      PCDH19  0.906593
# 5      PCDH19  0.906593
# 6         NF1  0.922413
# ...       ...       ...
# 10539   PDHA1  0.894737
# 10541  SRD5A2  0.921053
# 10542  SRD5A2  0.921053
# 10543  SRD5A2  0.921053
# 10544    HBA2  0.937500
#
# [8946 rows x 17 columns]

# %%
# Splitting the data
benign_data = auc_full_data[auc_full_data['label'] == 0]
malign_data = auc_full_data[auc_full_data['label'] == 1]

# %%
# Violinplot of the benign labeled samples, with their capice scores and AUC of the genes the SNVs are in.
benign_subset = benign_data[['capice','auc']]
numpy_b_sub = np.array(benign_subset)
print(numpy_b_sub.size)
plt.violinplot(numpy_b_sub)
plt.show()
# Out:
# 7320

# %%
# Violinplot of the malignant labeled samples, with their capice scores and AUC of the genes the SNVs are in.
malign_subset = malign_data[['capice','auc']]
numpy_b_sub = np.array(malign_subset)
print(numpy_b_sub.size)
plt.violinplot(numpy_b_sub)
plt.show()

# From these plots, I see that more pathogenic samples are present, but also pathogenic is more accurate.
# Out:
# 10572

# %%
# Some statistics on the distributions of the capice scores between Malignant and Benign
perform_stats(benign_data['capice'], malign_data['capice'])
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 1.0
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 0.0
# Pearson correlation could not be performed!
# /usr/lib/python3.8/site-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
# Scatter plot of the capice scores vs the auc in benign and malignant samples.
fig = plt.figure(figsize=(15,10))
axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.scatter(malign_subset['capice'], malign_subset['auc'], c='red', label='Malignant', s=1)
axes.scatter(benign_subset['capice'], benign_subset['auc'], c='blue', label='Benigne', s=1)
axes.set_xlabel("CAPICE")
axes.set_ylabel("auc")
axes.set_title("CAPICE score vs AUC")
axes.legend()
plt.show()

perform_stats(malign_subset['auc'], benign_subset['auc'])

t2, p2 = stats.ttest_ind(malign_subset['auc'],benign_subset['auc'], equal_var=False)
if p2 >= 0.05:
    print(f'We fail to reject H0 hypothesis. P = {p2}')
else:
    print(f'We have statistical power to reject H0 hypothesis. P = {p2}')
# P < 0.05, so we can accept H0.
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 1.0
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 9.492438049817537e-73
# Pearson correlation could not be performed!
# We have statistical power to reject H0 hypothesis. P = 8.840980734389197e-116

# %%
# Sorting malignant samples to find genes that spring out.

malign_data.sort_values(by=['auc','capice'], ascending=True)
# From these results, there is not really a gene that springs out, at least (see next code block)
# Out:
#       #Chrom        Pos     Ref    Alt    max_AF     Consequence  label  \
# 8713      14   78043194       G      A  0.000045  NON_SYNONYMOUS      1
# 4694       4  140291436  GAAGAA      G  0.000000     FRAME_SHIFT      1
# 4036      12   46230586       A  AAACG  0.000000     FRAME_SHIFT      1
# 4113       2   72725621       A      C  0.000000     STOP_GAINED      1
# 9700       X   41205629       G      A  0.000000  NON_SYNONYMOUS      1
# ...      ...        ...     ...    ...       ...             ...    ...
# 9190      19   55665513       C      T  0.000116  NON_SYNONYMOUS      1
# 10329     17   33902991     AAG      A  0.000617     FRAME_SHIFT      1
# 10530      1   63868019       G      A  0.000969     SPLICE_SITE      1
# 10264      9   37424858      TG      T  0.000501     FRAME_SHIFT      1
# 9651       6   80878662       G      C  0.013245  NON_SYNONYMOUS      1
#
#        revel  clinpred   sift  provean  PHRED  fathmm_score    capice  ponp2  \
# 8713   0.119  0.948083  0.999     3.10   23.9           NaN  0.004144  0.766
# 4694     NaN       NaN    NaN      NaN   35.0           NaN  0.316003    NaN
# 4036     NaN       NaN    NaN      NaN   31.0           NaN  0.454109    NaN
# 4113     NaN       NaN    NaN      NaN   35.0           NaN  0.054396    NaN
# 9700   0.743       NaN  1.000     4.29   26.2           NaN  0.669419  0.798
# ...      ...       ...    ...      ...    ...           ...       ...    ...
# 9190   0.800  0.966117  0.997     2.82   27.1           NaN  0.990257  0.743
# 10329    NaN       NaN    NaN      NaN   24.2           NaN  0.991165    NaN
# 10530    NaN       NaN    NaN      NaN   22.4           NaN  0.991705    NaN
# 10264    NaN       NaN    NaN      NaN   33.0           NaN  0.993465    NaN
# 9651   0.972  0.916217  1.000     6.81   31.0      0.966856  0.997698  0.903
#
#          gene       auc
# 8713   SPTLC2  0.458937
# 4694    NAA15  0.607143
# 4036    ARID2  0.652174
# 4113   EXOC6B  0.700000
# 9700    DDX3X  0.700000
# ...       ...       ...
# 9190    TNNI3  1.000000
# 10329   PEX12  1.000000
# 10530    ALG6  1.000000
# 10264   GRHPR  1.000000
# 9651   BCKDHB  1.000000
#
# [5286 rows x 17 columns]

# %%
malign_data[malign_data['gene'] == 'SPTLC2'].sort_values(by=['auc', 'capice'], ascending=True)
# There is only 1 malignant variant of SPTLC2 and (see next code block)
# Out:
#      #Chrom       Pos Ref Alt    max_AF     Consequence  label  revel  \
# 8713     14  78043194   G   A  0.000045  NON_SYNONYMOUS      1  0.119
#
#       clinpred   sift  provean  PHRED  fathmm_score    capice  ponp2    gene  \
# 8713  0.948083  0.999      3.1   23.9           NaN  0.004144  0.766  SPTLC2
#
#            auc
# 8713  0.458937

# %%
benign_data[benign_data['gene'] == 'SPTLC2'].sort_values(by=['auc', 'capice'], ascending=True)
# there is also only 1 benign variant. Too less data perhaps? (see next code block)
# Out:
#      #Chrom       Pos Ref Alt    max_AF     Consequence  label  revel  \
# 8712     14  78043131   A   G  0.000009  NON_SYNONYMOUS      0   0.59
#
#       clinpred   sift  provean  PHRED  fathmm_score    capice  ponp2    gene  \
# 8712  0.988399  0.992     7.79   26.4      0.666947  0.050683  0.947  SPTLC2
#
#            auc
# 8712  0.458937

# %%
data[data['Gene'] == 'SPTLC2']
# Could indicate overfitting to pathogenic.
# It has been trained on 207 benign and 1 malignant variant. The benign test sample performs well, with a low capice score, but
# the malignant variant performs poorly because of overfitting on benign training samples.

# Possible that the train data was imbalanced after all?
# Out:
#         Gene       AUC  FPR  Precision  Recall/TPR  F-score  N_benign  \
# 2422  SPTLC2  0.458937  1.0        0.0         0.0      0.0       207
#
#       N_malign  m_cat  n_snvs  b/p ratio
# 2422         1      1     208      207.0

# %%
# Sorting the benign dataset on the AUC and capice scores.

benign_data.sort_values(by=['auc','capice'], ascending=True)
# From these results, GFM2 might be problematic for CAPICE
# Out:
#      #Chrom        Pos  Ref Alt    max_AF       Consequence  label  revel  \
# 4831      5   74034349    G  GA  0.000009       FRAME_SHIFT      0    NaN
# 4825      5   74034412    G   A  0.000045       STOP_GAINED      0    NaN
# 4828      5   74041526    C  CT  0.000033       FRAME_SHIFT      0    NaN
# 4823      5   74041501    A   T  0.000066  CANONICAL_SPLICE      0    NaN
# 4827      5   74041534   GT   G  0.000116       FRAME_SHIFT      0    NaN
# ...     ...        ...  ...  ..       ...               ...    ...    ...
# 7473      2  136872570   TA   T  0.000009       FRAME_SHIFT      0    NaN
# 7600      9  131085372   GG   G  0.000000       FRAME_SHIFT      0    NaN
# 3190      2  228155509  AAG   A  0.000030       FRAME_SHIFT      0    NaN
# 2141      9  131295876   TC   T  0.000004       FRAME_SHIFT      0    NaN
# 6994     11    1862428   CA   C  0.000030       FRAME_SHIFT      0    NaN
#
#       clinpred  sift  provean  PHRED  fathmm_score    capice  ponp2    gene  \
# 4831       NaN   NaN      NaN   31.0           NaN  0.113844    NaN    GFM2
# 4825       NaN   NaN      NaN   39.0           NaN  0.138325    NaN    GFM2
# 4828       NaN   NaN      NaN   35.0           NaN  0.222382    NaN    GFM2
# 4823       NaN   NaN      NaN   34.0      0.991363  0.302115    NaN    GFM2
# 4827       NaN   NaN      NaN   29.2           NaN  0.673495    NaN    GFM2
# ...        ...   ...      ...    ...           ...       ...    ...     ...
# 7473       NaN   NaN      NaN   34.0           NaN  0.836804    NaN   CXCR4
# 7600       NaN   NaN      NaN   23.8           NaN  0.886964    NaN    COQ4
# 3190       NaN   NaN      NaN   33.0           NaN  0.887617    NaN  COL4A3
# 2141       NaN   NaN      NaN   26.7           NaN  0.954905    NaN    GLE1
# 6994       NaN   NaN      NaN   34.0           NaN  0.961129    NaN   TNNI2
#
#            auc
# 4831  0.404762
# 4825  0.404762
# 4828  0.404762
# 4823  0.404762
# 4827  0.404762
# ...        ...
# 7473  1.000000
# 7600  1.000000
# 3190  1.000000
# 2141  1.000000
# 6994  1.000000
#
# [3660 rows x 17 columns]

# %%
auc_snv_data[auc_snv_data['gene'] == 'GFM2']
# Out:
#      #Chrom       Pos  Ref Alt    max_AF       Consequence label  revel  \
# 4823      5  74041501    A   T  0.000066  CANONICAL_SPLICE  LB/B    NaN
# 4824      5  74055252    C   T  0.000009  CANONICAL_SPLICE  LB/B    NaN
# 4825      5  74034412    G   A  0.000045       STOP_GAINED  LB/B    NaN
# 4826      5  74041940    A   T  0.000020       STOP_GAINED  LB/B    NaN
# 4827      5  74041534   GT   G  0.000116       FRAME_SHIFT  LB/B    NaN
# 4828      5  74041526    C  CT  0.000033       FRAME_SHIFT  LB/B    NaN
# 4829      5  74056758   CA   C  0.000009       FRAME_SHIFT  LB/B    NaN
# 4830      5  74043593  TGA   T  0.000033       FRAME_SHIFT  LB/B    NaN
# 4831      5  74034349    G  GA  0.000009       FRAME_SHIFT  LB/B    NaN
#
#       clinpred  sift  provean  PHRED  fathmm_score    capice  ponp2  gene  \
# 4823       NaN   NaN      NaN  34.00      0.991363  0.302115    NaN  GFM2
# 4824       NaN   NaN      NaN  24.70           NaN  0.836535    NaN  GFM2
# 4825       NaN   NaN      NaN  39.00           NaN  0.138325    NaN  GFM2
# 4826       NaN   NaN      NaN  37.00           NaN  0.678795    NaN  GFM2
# 4827       NaN   NaN      NaN  29.20           NaN  0.673495    NaN  GFM2
# 4828       NaN   NaN      NaN  35.00           NaN  0.222382    NaN  GFM2
# 4829       NaN   NaN      NaN  17.85           NaN  0.993191    NaN  GFM2
# 4830       NaN   NaN      NaN  35.00           NaN  0.833748    NaN  GFM2
# 4831       NaN   NaN      NaN  31.00           NaN  0.113844    NaN  GFM2
#
#            auc
# 4823  0.404762
# 4824  0.404762
# 4825  0.404762
# 4826  0.404762
# 4827  0.404762
# 4828  0.404762
# 4829  0.404762
# 4830  0.404762
# 4831  0.404762

# %%
data[data['Gene'] == 'GFM2']
# It has been trained on mostly benign samples, but the capice scores are too high. Cause?
# Out:
#       Gene       AUC  FPR  Precision  Recall/TPR  F-score  N_benign  N_malign  \
# 2353  GFM2  0.404762  1.0        0.0         0.0      0.0       105         2
#
#       m_cat  n_snvs  b/p ratio
# 2353      1     107       52.5

# %%
# New dataset that contains a 1 if the variant is exonic or 0 if intronic. 
# Exons are from the Agilent exoom v3 human bed file.
# Since a compressed version of that file was used to find the gene for each variant,
# if a variant was not in the areas of the full Agilent file, it was marked as intronic.

intronic_exonic_dataset = pd.read_csv("/home/"+location+"/Documents/School/Master_DSLS/Final_Thesis/Initial_Data_exploration/test_results_genes_auc_exonic.csv", header=0, index_col=0)
intronic_exonic_dataset
# Out:
#       #Chrom       Pos      Ref Alt    max_AF       Consequence label  revel  \
# 0         21  33974174        C   G  0.000058         STOP_LOST  LB/B    NaN
# 1         21  33974278        C  CA  0.000045       FRAME_SHIFT  LB/B    NaN
# 2          X  99661625        G   C  0.000037        SYNONYMOUS  LB/B    NaN
# 3          X  99663098        G  GT  0.000013       STOP_GAINED  LB/B    NaN
# 4          X  99662275        C   G  0.000212    NON_SYNONYMOUS  LB/B  0.527
# ...      ...       ...      ...  ..       ...               ...   ...    ...
# 10540     22  36662041  AATAATT   A  0.141400           INFRAME  LP/P    NaN
# 10541      2  31754497        T   C  0.000033  NONCODING_CHANGE  LP/P    NaN
# 10542      2  31754393        C   T  0.000000  NONCODING_CHANGE  LP/P    NaN
# 10543      2  31758741        T   C  0.000200  NONCODING_CHANGE  LP/P    NaN
# 10544     16    223597        T   C  0.001252         STOP_LOST  LP/P    NaN
#
#        clinpred  sift  provean   PHRED  fathmm_score    capice  ponp2  \
# 0           NaN   NaN      NaN  15.050           NaN  0.003275    NaN
# 1           NaN   NaN      NaN  35.000           NaN  0.304741    NaN
# 2           NaN  0.00    -0.00   0.806           NaN  0.000075    NaN
# 3           NaN   NaN      NaN  35.000           NaN  0.998694    NaN
# 4           NaN  0.95     2.51  27.000           NaN  0.863940  0.436
# ...         ...   ...      ...     ...           ...       ...    ...
# 10540       NaN   NaN     8.98   7.508           NaN  0.004829    NaN
# 10541       NaN   NaN      NaN  19.790      0.951270  0.918898    NaN
# 10542       NaN   NaN      NaN  21.700           NaN  0.985064    NaN
# 10543       NaN   NaN      NaN  20.800      0.912937  0.474717    NaN
# 10544       NaN   NaN      NaN  18.020           NaN  0.971616    NaN
#
#            gene       auc  exonic
# 0      C21orf59       NaN       1
# 1      C21orf59       NaN       1
# 2        PCDH19  0.906593       1
# 3        PCDH19  0.906593       1
# 4        PCDH19  0.906593       1
# ...         ...       ...     ...
# 10540     APOL1       NaN       1
# 10541    SRD5A2  0.921053       0
# 10542    SRD5A2  0.921053       0
# 10543    SRD5A2  0.921053       0
# 10544      HBA2  0.937500       1
#
# [10545 rows x 18 columns]

# %%
# Searching for GFM2
intronic_exonic_dataset[intronic_exonic_dataset['gene'] == 'GFM2']

# All of the variants are intronic according to the Agilent exon list. 

# Does capice take introns/exons into account?
    # No it does not.
# Out:
#      #Chrom       Pos  Ref Alt    max_AF       Consequence label  revel  \
# 4823      5  74041501    A   T  0.000066  CANONICAL_SPLICE  LB/B    NaN
# 4824      5  74055252    C   T  0.000009  CANONICAL_SPLICE  LB/B    NaN
# 4825      5  74034412    G   A  0.000045       STOP_GAINED  LB/B    NaN
# 4826      5  74041940    A   T  0.000020       STOP_GAINED  LB/B    NaN
# 4827      5  74041534   GT   G  0.000116       FRAME_SHIFT  LB/B    NaN
# 4828      5  74041526    C  CT  0.000033       FRAME_SHIFT  LB/B    NaN
# 4829      5  74056758   CA   C  0.000009       FRAME_SHIFT  LB/B    NaN
# 4830      5  74043593  TGA   T  0.000033       FRAME_SHIFT  LB/B    NaN
# 4831      5  74034349    G  GA  0.000009       FRAME_SHIFT  LB/B    NaN
#
#       clinpred  sift  provean  PHRED  fathmm_score    capice  ponp2  gene  \
# 4823       NaN   NaN      NaN  34.00      0.991363  0.302115    NaN  GFM2
# 4824       NaN   NaN      NaN  24.70           NaN  0.836535    NaN  GFM2
# 4825       NaN   NaN      NaN  39.00           NaN  0.138325    NaN  GFM2
# 4826       NaN   NaN      NaN  37.00           NaN  0.678795    NaN  GFM2
# 4827       NaN   NaN      NaN  29.20           NaN  0.673495    NaN  GFM2
# 4828       NaN   NaN      NaN  35.00           NaN  0.222382    NaN  GFM2
# 4829       NaN   NaN      NaN  17.85           NaN  0.993191    NaN  GFM2
# 4830       NaN   NaN      NaN  35.00           NaN  0.833748    NaN  GFM2
# 4831       NaN   NaN      NaN  31.00           NaN  0.113844    NaN  GFM2
#
#            auc  exonic
# 4823  0.404762       0
# 4824  0.404762       0
# 4825  0.404762       0
# 4826  0.404762       0
# 4827  0.404762       0
# 4828  0.404762       0
# 4829  0.404762       0
# 4830  0.404762       0
# 4831  0.404762       0

# %%
# Data splitting.

auc_exon = intronic_exonic_dataset[intronic_exonic_dataset['exonic'] == 1][['gene','capice','auc']]
auc_intron = intronic_exonic_dataset[intronic_exonic_dataset['exonic'] == 0][['gene','capice','auc']]

# %%
# More data splitting for scatter plotting.
# Simular to the first scatter plot, to find possible patterns within the dataset.
auc_exon_detailed = intronic_exonic_dataset[intronic_exonic_dataset['exonic'] == 1][['gene','capice','auc','label']]
auc_intron_detailed = intronic_exonic_dataset[intronic_exonic_dataset['exonic'] == 0][['gene','capice','auc','label']]
benign_aed = auc_exon_detailed[auc_exon_detailed['label'] == 'LB/B']
malign_aed = auc_exon_detailed[auc_exon_detailed['label'] == 'LP/P']
benign_aid = auc_intron_detailed[auc_intron_detailed['label'] == 'LB/B']
malign_aid = auc_intron_detailed[auc_intron_detailed['label'] == 'LP/P']

fig = plt.figure(figsize=(15,10))
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.scatter(benign_aed['capice'], benign_aed['auc'], c='red', label='Benign Exons', s=1)
# axes.scatter(malign_aed['capice'], malign_aed['auc'], c='blue', label='Malign Exons', s=1)
axes.scatter(benign_aid['capice'], benign_aid['auc'], c='purple', label='Benign Introns', s=1)
# axes.scatter(malign_aid['capice'], malign_aid['auc'], c='orange', label='Malign Introns', s=1)
axes.set_xlabel("CAPICE")
axes.set_ylabel("auc")
axes.set_title("X1Y1 vs X2Y2")
axes.legend()
plt.show()

# Some statistics on the various datasets.
print("\n'Benign'")
perform_stats(benign_aed['capice'], benign_aid['capice'])
print("\n'Malignant'")
perform_stats(malign_aed['capice'], malign_aid['capice'])
print("\n'Benign Intron, Malignant Intron'")
perform_stats(benign_aid['capice'], malign_aid['capice'])
print("\n'Benign Exon, Malignant Exon'")
perform_stats(benign_aed['capice'], malign_aed['capice'])
print("\n'Benign Intron, Malignant Exon'")
perform_stats(benign_aid['capice'], malign_aed['capice'])
print("\n'Benign Exon, Malignant Intron'")
perform_stats(benign_aed['capice'], malign_aid['capice'])
print("\n'Exons vs Introns'")
perform_stats(auc_exon_detailed['capice'], auc_intron_detailed['capice'])
# Will coxon test
# Out:
# 'Benign'
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 1.0
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 0.2530791659900159
# Pearson correlation could not be performed!
#
# 'Malignant'
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 0.9985101505880065
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 1.3286908254119973e-101
# Pearson correlation could not be performed!
#
# 'Benign Intron, Malignant Intron'
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 0.9999999999886016
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 0.0
# Pearson correlation could not be performed!
#
# 'Benign Exon, Malignant Exon'
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 0.7803459091340439
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 0.0
# Pearson correlation could not be performed!
#
# 'Benign Intron, Malignant Exon'
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 0.9999999999999983
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 0.0
# Pearson correlation could not be performed!
#
# 'Benign Exon, Malignant Intron'
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 0.0071908880993075686
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 0.0
# Pearson correlation could not be performed!
#
# 'Exons vs Introns'
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 1.0
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 9.705493001426448e-106
# Pearson correlation could not be performed!
# /usr/lib/python3.8/site-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
# Early project statistics, using Levene's test and student t-test to see if samples are simular.

_, lev_pexbm = stats.levene(benign_aed['auc'].dropna(), malign_aed['auc'].dropna())
if lev_pexbm >= 0.05:
    e_q_var_pexbm = False
else:
    e_q_var_pexbm = True
    
_, lev_pexinb = stats.levene(benign_aed['auc'].dropna(), benign_aid['auc'].dropna())
if lev_pexinb >= 0.05:
    e_q_var_pexinb = False
else:
    e_q_var_pexinb = True
    
_, lev_pexinm = stats.levene(malign_aed['auc'].dropna(), malign_aid['auc'].dropna())
if lev_pexinm >= 0.05:
    e_q_var_pexinm = False
else:
    e_q_var_pexinm = True
    
_, lev_pinbm = stats.levene(benign_aid['auc'].dropna(), malign_aid['auc'].dropna())
if lev_pinbm >= 0.05:
    e_q_var_pinbm = False
else:
    e_q_var_pinbm = True

t2, p_ex_bm = stats.ttest_ind(benign_aed['auc'].dropna(), malign_aed['auc'].dropna(), equal_var=e_q_var_pexbm)
t2, p_ex_in_b = stats.ttest_ind(benign_aed['auc'].dropna(), benign_aid['auc'].dropna(), equal_var=e_q_var_pexinb)
t2, p_ex_in_m = stats.ttest_ind(malign_aed['auc'].dropna(), malign_aid['auc'].dropna(), equal_var=e_q_var_pexinm)
t2, p_in_bm = stats.ttest_ind(benign_aid['auc'].dropna(), malign_aid['auc'].dropna(), equal_var=False)

print(f'Exons, benign malign: {p_ex_bm}. With lev: {e_q_var_pexbm}. \n'
     f'Exon, intron benign: {p_ex_in_b}. With lev: {e_q_var_pexbm}.\n'
     f'Exon, intron malign: {p_ex_in_m}. \n'
     f'Intron, benign malign: {p_in_bm}.')

# Test again, but in will coxon test.
# Out:
# Exons, benign malign: 4.106182017721228e-90. With lev: True.
# Exon, intron benign: 0.022393800189555748. With lev: True.
# Exon, intron malign: 9.706396170816319e-15.
# Intron, benign malign: 5.701290472292696e-73.

# %%
# Are they different? Let's student t test it!

auc_exon2 = auc_exon['auc'].dropna()
auc_intron2 = auc_intron['auc'].dropna()

perform_stats(auc_exon2,auc_intron2)

t2, p2 = stats.ttest_ind(auc_exon2,auc_intron2, equal_var=False)
if p2 >= 0.05:
    print(f'We fail to reject H0 hypothesis. P = {p2}')
else:
    print(f'We have statistical power to reject H0 hypothesis. P = {p2}')
    
# Actually illegal student t-tests, since the samples are not distributed normally.
# Out:
# X is likely not normally distributed.
# Y is likely not normally distributed.
# The Kolmogorov-Smirnov test p-value: 1.0
# Wilcoxon could not be performed,
# Using Mann-Whitney rank test p-value: 2.325699361498863e-20
# Pearson correlation could not be performed!
# We fail to reject H0 hypothesis. P = 0.5044278321291654

# %%
# Adding more stats to my intronic/exonic dataset.
# Adding the number of train samples and the number of pathogenic train samples the gene of that 
# variant.

intronic_exonic_dataset['n_test'] = 0
intronic_exonic_dataset['n_test_malign'] = 0
reset_timer = time.time()
done_rows = 0
total_rows = intronic_exonic_dataset.shape[0]
for row in intronic_exonic_dataset.iterrows():
    timer_ifl = time.time()
    if timer_ifl - reset_timer > 10:
        print(f"Still running, done: {round(done_rows / total_rows * 100, ndigits=2)}&")
        reset_timer = time.time()
    index = row[0]
    row = row[1]
    gene_req = row['gene']
    if data[data['Gene'] == gene_req]['n_snvs'].shape[0] != 1:
        n_test_gene = np.NaN
        n_malign_train = np.NaN
    else:
        n_test_gene = data[data['Gene'] == gene_req]['n_snvs'].item()
        n_malign_train = data[data['Gene'] == gene_req]['N_malign'].item()
    intronic_exonic_dataset.loc[index, 'n_test'] = n_test_gene
    intronic_exonic_dataset.loc[index, 'n_test_malign'] = n_malign_train
    done_rows += 1

intronic_exonic_dataset
# Out:
# Still running, done: 12.99&
# Still running, done: 28.24&
# Still running, done: 43.53&
# Still running, done: 58.5&
# Still running, done: 73.14&
# Still running, done: 88.48&
#       #Chrom       Pos      Ref Alt    max_AF       Consequence label  revel  \
# 0         21  33974174        C   G  0.000058         STOP_LOST  LB/B    NaN
# 1         21  33974278        C  CA  0.000045       FRAME_SHIFT  LB/B    NaN
# 2          X  99661625        G   C  0.000037        SYNONYMOUS  LB/B    NaN
# 3          X  99663098        G  GT  0.000013       STOP_GAINED  LB/B    NaN
# 4          X  99662275        C   G  0.000212    NON_SYNONYMOUS  LB/B  0.527
# ...      ...       ...      ...  ..       ...               ...   ...    ...
# 10540     22  36662041  AATAATT   A  0.141400           INFRAME  LP/P    NaN
# 10541      2  31754497        T   C  0.000033  NONCODING_CHANGE  LP/P    NaN
# 10542      2  31754393        C   T  0.000000  NONCODING_CHANGE  LP/P    NaN
# 10543      2  31758741        T   C  0.000200  NONCODING_CHANGE  LP/P    NaN
# 10544     16    223597        T   C  0.001252         STOP_LOST  LP/P    NaN
#
#        clinpred  sift  provean   PHRED  fathmm_score    capice  ponp2  \
# 0           NaN   NaN      NaN  15.050           NaN  0.003275    NaN
# 1           NaN   NaN      NaN  35.000           NaN  0.304741    NaN
# 2           NaN  0.00    -0.00   0.806           NaN  0.000075    NaN
# 3           NaN   NaN      NaN  35.000           NaN  0.998694    NaN
# 4           NaN  0.95     2.51  27.000           NaN  0.863940  0.436
# ...         ...   ...      ...     ...           ...       ...    ...
# 10540       NaN   NaN     8.98   7.508           NaN  0.004829    NaN
# 10541       NaN   NaN      NaN  19.790      0.951270  0.918898    NaN
# 10542       NaN   NaN      NaN  21.700           NaN  0.985064    NaN
# 10543       NaN   NaN      NaN  20.800      0.912937  0.474717    NaN
# 10544       NaN   NaN      NaN  18.020           NaN  0.971616    NaN
#
#            gene       auc  exonic  n_test  n_test_malign
# 0      C21orf59       NaN       1    19.0            0.0
# 1      C21orf59       NaN       1    19.0            0.0
# 2        PCDH19  0.906593       1   177.0           86.0
# 3        PCDH19  0.906593       1   177.0           86.0
# 4        PCDH19  0.906593       1   177.0           86.0
# ...         ...       ...     ...     ...            ...
# 10540     APOL1       NaN       1    81.0            0.0
# 10541    SRD5A2  0.921053       0    30.0           19.0
# 10542    SRD5A2  0.921053       0    30.0           19.0
# 10543    SRD5A2  0.921053       0    30.0           19.0
# 10544      HBA2  0.937500       1    26.0           18.0
#
# [10545 rows x 20 columns]

# %%
intronic_exonic_dataset[intronic_exonic_dataset['n_test'].isna()]

# Gene is NaN and label is only LB/B. Accidental slip ins or variants in regularitory areas?
# Out:
#      #Chrom        Pos                      Ref    Alt    max_AF  \
# 2174      8  133492864                        G      A  0.003077
# 2175     12   56583325  CCCGCCGCCTCCCGCCGCCGCGG      C  0.000442
# 2176      1  231559243                        C      T  0.001601
# 2177      3   45430178                        C      A  0.000000
# 2178      9  116163571                        G     GG  0.000000
# 2179      6  163148775                        A      G  0.000125
# 2180      4    1901007                        C      T  0.000000
# 2181     15   63349381                       CC      C  0.000000
# 2182      5   88178755                        A      T  0.000115
# 2183     13   22245256                        C      T  0.001812
# 2184     21   47518072                        G      T  0.000000
# 2185      1  198828293                   CACTTT      C  0.000033
# 2186      9  101911947                        A      G  0.007334
# 2187     11   31810641                        G      A  0.001196
# 2188      2  158731389                        T      C  0.000032
# 2189      1   46664025                        C      T  0.000067
# 2190     13   32889784                        A      G  0.000000
# 2191      4  128886365                        T      G  0.000267
# 2192      1  200587968                        T      A  0.000145
# 2193     12   49415100                        G     GG  0.000000
# 2194      3   10195044                        C      T  0.004626
# 2195      1  145510732                        G      T  0.000099
# 2196      X  123506930                        C      A  0.001711
# 2197      2  219919681                        G      T  0.007104
# 2198      6   73110699                        A      G  0.003580
# 2199      1  145515453                        T      C  0.000617
# 2200     13  102373292                        A  AATCA  0.000000
# 2201     10   90694470                      AGT      A  0.000000
# 2202      9  130265235                        G      A  0.006622
# 2203      8   38271033                        C      T  0.006622
# 2204     16   68678654                        A     AA  0.000000
# 2205      2  209221528                        T      G  0.008592
# 2206     19    7114812                        A      C  0.001001
# 2207     12    2802988                        A      G  0.006782
# 2208     17   40466638                        C      T  0.000067
# 2209     18   55214377                        C      T  0.009064
# 2210     13   37421821                        C      T  0.007859
# 2211      9   35657869                        C      T  0.000127
# 2212     22   24176449                        C      T  0.000000
# 2213      9  104197990                        C      G  0.001193
# 2214     19   11200090                        C      G  0.000000
# 2215     19   11200089                        C      T  0.000000
# 2216      5  149340544                        T      C  0.006590
#
#            Consequence label  revel  clinpred   sift  provean   PHRED  \
# 2174        5PRIME_UTR  LB/B    NaN       NaN    NaN      NaN  17.320
# 2175        5PRIME_UTR  LB/B    NaN       NaN    NaN      NaN  16.160
# 2176        5PRIME_UTR  LB/B    NaN       NaN    NaN      NaN   5.848
# 2177        REGULATORY  LB/B    NaN       NaN    NaN      NaN  12.570
# 2178        REGULATORY  LB/B    NaN       NaN    NaN      NaN  13.960
# 2179        REGULATORY  LB/B    NaN       NaN    NaN      NaN  10.020
# 2180        REGULATORY  LB/B    NaN       NaN    NaN      NaN   5.730
# 2181          INTRONIC  LB/B    NaN       NaN    NaN      NaN   6.580
# 2182          UPSTREAM  LB/B    NaN       NaN    NaN      NaN  22.500
# 2183          UPSTREAM  LB/B    NaN       NaN    NaN      NaN  22.500
# 2184          UPSTREAM  LB/B    NaN       NaN    NaN      NaN  13.630
# 2185          UPSTREAM  LB/B    NaN       NaN    NaN      NaN  16.170
# 2186          UPSTREAM  LB/B    NaN       NaN    NaN      NaN  10.150
# 2187          UPSTREAM  LB/B    NaN       NaN    NaN      NaN  21.500
# 2188          UPSTREAM  LB/B    NaN       NaN    NaN      NaN   7.532
# 2189          UPSTREAM  LB/B    NaN       NaN    NaN      NaN  15.390
# 2190          UPSTREAM  LB/B    NaN       NaN    NaN      NaN   8.451
# 2191  CANONICAL_SPLICE  LB/B    NaN       NaN    NaN      NaN  22.000
# 2192  CANONICAL_SPLICE  LB/B    NaN       NaN    NaN      NaN  16.810
# 2193        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN  19.490
# 2194        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   0.313
# 2195        DOWNSTREAM  LB/B  0.017       NaN  0.745      0.9   9.048
# 2196        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   0.054
# 2197        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   6.176
# 2198        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   3.031
# 2199        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN  15.480
# 2200        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN  18.880
# 2201        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   0.252
# 2202        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   0.762
# 2203        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   1.452
# 2204        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   6.827
# 2205        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   7.041
# 2206        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN  13.130
# 2207        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   0.969
# 2208        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN  10.130
# 2209        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   1.877
# 2210        DOWNSTREAM  LB/B    NaN       NaN    NaN      NaN   0.326
# 2211        DOWNSTREAM  LP/P    NaN       NaN    NaN      NaN  20.400
# 2212        DOWNSTREAM  LP/P    NaN       NaN    NaN      NaN   8.718
# 2213  CANONICAL_SPLICE  LP/P    NaN       NaN    NaN      NaN  33.000
# 2214        REGULATORY  LP/P    NaN       NaN    NaN      NaN  16.190
# 2215        REGULATORY  LP/P    NaN       NaN    NaN      NaN  21.000
# 2216        REGULATORY  LP/P    NaN       NaN    NaN      NaN  26.700
#
#       fathmm_score    capice  ponp2 gene  auc  exonic  n_test  n_test_malign
# 2174           NaN  0.000113    NaN  NaN  NaN       0     NaN            NaN
# 2175           NaN  0.004680    NaN  NaN  NaN       0     NaN            NaN
# 2176           NaN  0.000290    NaN  NaN  NaN       0     NaN            NaN
# 2177           NaN  0.000451    NaN  NaN  NaN       0     NaN            NaN
# 2178           NaN  0.000968    NaN  NaN  NaN       0     NaN            NaN
# 2179           NaN  0.000113    NaN  NaN  NaN       0     NaN            NaN
# 2180           NaN  0.000068    NaN  NaN  NaN       0     NaN            NaN
# 2181           NaN  0.001253    NaN  NaN  NaN       0     NaN            NaN
# 2182      0.844183  0.037625    NaN  NaN  NaN       0     NaN            NaN
# 2183           NaN  0.002467    NaN  NaN  NaN       0     NaN            NaN
# 2184           NaN  0.000884    NaN  NaN  NaN       0     NaN            NaN
# 2185           NaN  0.000653    NaN  NaN  NaN       0     NaN            NaN
# 2186           NaN  0.000014    NaN  NaN  NaN       0     NaN            NaN
# 2187      0.860419  0.000972    NaN  NaN  NaN       0     NaN            NaN
# 2188      0.135494  0.000334    NaN  NaN  NaN       0     NaN            NaN
# 2189           NaN  0.000205    NaN  NaN  NaN       0     NaN            NaN
# 2190           NaN  0.000083    NaN  NaN  NaN       0     NaN            NaN
# 2191           NaN  0.543657    NaN  NaN  NaN       0     NaN            NaN
# 2192           NaN  0.027515    NaN  NaN  NaN       0     NaN            NaN
# 2193           NaN  0.004450    NaN  NaN  NaN       0     NaN            NaN
# 2194      0.049762  0.000195    NaN  NaN  NaN       0     NaN            NaN
# 2195      0.292448  0.000028    NaN  NaN  NaN       0     NaN            NaN
# 2196           NaN  0.000268    NaN  NaN  NaN       0     NaN            NaN
# 2197      0.219749  0.000082    NaN  NaN  NaN       0     NaN            NaN
# 2198           NaN  0.000276    NaN  NaN  NaN       0     NaN            NaN
# 2199      0.027709  0.000199    NaN  NaN  NaN       0     NaN            NaN
# 2200           NaN  0.002027    NaN  NaN  NaN       0     NaN            NaN
# 2201           NaN  0.000044    NaN  NaN  NaN       0     NaN            NaN
# 2202      0.075278  0.000004    NaN  NaN  NaN       0     NaN            NaN
# 2203           NaN  0.000014    NaN  NaN  NaN       0     NaN            NaN
# 2204           NaN  0.000789    NaN  NaN  NaN       0     NaN            NaN
# 2205           NaN  0.000398    NaN  NaN  NaN       0     NaN            NaN
# 2206           NaN  0.000074    NaN  NaN  NaN       0     NaN            NaN
# 2207           NaN  0.000018    NaN  NaN  NaN       0     NaN            NaN
# 2208           NaN  0.000107    NaN  NaN  NaN       0     NaN            NaN
# 2209           NaN  0.000044    NaN  NaN  NaN       0     NaN            NaN
# 2210      0.057786  0.000048    NaN  NaN  NaN       0     NaN            NaN
# 2211      0.879744  0.370758    NaN  NaN  NaN       0     NaN            NaN
# 2212      0.220278  0.000094    NaN  NaN  NaN       0     NaN            NaN
# 2213           NaN  0.933222    NaN  NaN  NaN       0     NaN            NaN
# 2214           NaN  0.850948    NaN  NaN  NaN       0     NaN            NaN
# 2215           NaN  0.984047    NaN  NaN  NaN       0     NaN            NaN
# 2216           NaN  0.860521    NaN  NaN  NaN       0     NaN            NaN

# %%
# Getting a list of the genes that were used in the molgenis plots.

list_of_plotted_genes = list(m_cat_filtered_usable['Gene'])

# %%
# Filtering the intronic exonic dataset to contain only genes that are plotted in the molgenis plots.

test_filter1 = pd.DataFrame(columns=intronic_exonic_dataset.columns)
reset_timer = time.time()
done_rows = 0
total_rows = intronic_exonic_dataset.shape[0]
for row in intronic_exonic_dataset.iterrows():
    time_ifl = time.time()
    if time_ifl - reset_timer > 10:
        print(f"Still running, done {round(done_rows / total_rows * 100, ndigits=2)}%.")
        reset_timer = time.time()
    row = row[1]
    if row['gene'] in list_of_plotted_genes:
        test_filter1 = test_filter1.append(row)
    done_rows += 1
# Out:
# Still running, done 13.02%.
# Still running, done 23.11%.
# Still running, done 33.81%.
# Still running, done 50.36%.
# Still running, done 64.14%.
# Still running, done 73.69%.
# Still running, done 84.25%.
# Still running, done 90.39%.
# Still running, done 95.7%.

# %%
# Setting some dtypes and sorting.

test_filter1 = test_filter1.astype({'n_test':'int32','n_test_malign':'int32'})

test_filter1.sort_values(by=['n_test', 'n_test_malign', 'auc', 'capice'], ascending=False)
# Out:
#       #Chrom        Pos           Ref  Alt    max_AF     Consequence label  \
# 535        2  179481608            AG    A  0.000000     FRAME_SHIFT  LP/P
# 512        2  179469476            AT    A  0.000000     FRAME_SHIFT  LP/P
# 414        2  179428493            AG    A  0.000009     FRAME_SHIFT  LB/B
# 494        2  179449659            GA    G  0.000000     FRAME_SHIFT  LP/P
# 357        2  179431247            TA    T  0.000030     FRAME_SHIFT  LB/B
# ...      ...        ...           ...  ...       ...             ...   ...
# 8627       1  165697319             C    T  0.003311  NON_SYNONYMOUS  LB/B
# 10280      9  100447259             G    A  0.000065     STOP_GAINED  LP/P
# 10279      9  100455945             A  ATT  0.000000     FRAME_SHIFT  LP/P
# 7529      14   57268651  GGTACCCATGGG    G  0.000000     FRAME_SHIFT  LP/P
# 7528      14   57272111            TA    T  0.000000     FRAME_SHIFT  LB/B
#
#        revel  clinpred   sift  provean  PHRED  fathmm_score    capice  ponp2  \
# 535      NaN       NaN    NaN      NaN   41.0           NaN  0.996111    NaN
# 512      NaN       NaN    NaN      NaN   45.0           NaN  0.996079    NaN
# 414      NaN       NaN    NaN      NaN   57.0           NaN  0.992506    NaN
# 494      NaN       NaN    NaN      NaN   49.0           NaN  0.992341    NaN
# 357      NaN       NaN    NaN      NaN   59.0           NaN  0.991003    NaN
# ...      ...       ...    ...      ...    ...           ...       ...    ...
# 8627   0.221  0.279363  0.986     2.24   28.4           NaN  0.137733   0.47
# 10280    NaN       NaN    NaN      NaN   35.0           NaN  0.683882    NaN
# 10279    NaN       NaN    NaN      NaN   34.0           NaN  0.605081    NaN
# 7529     NaN       NaN    NaN      NaN   35.0           NaN  0.973545    NaN
# 7528     NaN       NaN    NaN      NaN   18.2           NaN  0.877414    NaN
#
#         gene       auc exonic  n_test  n_test_malign
# 535      TTN  0.960966      0    4575            659
# 512      TTN  0.960966      0    4575            659
# 414      TTN  0.960966      0    4575            659
# 494      TTN  0.960966      0    4575            659
# 357      TTN  0.960966      0    4575            659
# ...      ...       ...    ...     ...            ...
# 8627   TMCO1  0.854167      0      14              6
# 10280    XPA  1.000000      0      13              6
# 10279    XPA  1.000000      0      13              6
# 7529    OTX2  0.785714      1      13              6
# 7528    OTX2  0.785714      1      13              6
#
# [7075 rows x 20 columns]

# %%
# OTX2 might be interesting.

test_filter1[test_filter1['gene'] == 'OTX2']
# Out:
#      #Chrom       Pos           Ref Alt  max_AF  Consequence label  revel  \
# 7528     14  57272111            TA   T     0.0  FRAME_SHIFT  LB/B    NaN
# 7529     14  57268651  GGTACCCATGGG   G     0.0  FRAME_SHIFT  LP/P    NaN
#
#       clinpred  sift  provean  PHRED  fathmm_score    capice  ponp2  gene  \
# 7528       NaN   NaN      NaN   18.2           NaN  0.877414    NaN  OTX2
# 7529       NaN   NaN      NaN   35.0           NaN  0.973545    NaN  OTX2
#
#            auc exonic  n_test  n_test_malign
# 7528  0.785714      1      13              6
# 7529  0.785714      1      13              6

# %%
# A list of genes, that is present in molgenis plots, ordered by AUC.

test_filter1.sort_values(by=['auc'],ascending=True)['gene'].unique()
# Out:
# array(['ARID2', 'EBF3', 'RPL5', 'DDX3X', 'ZMYND11', 'PHIP', 'PUF60',
#        'PDE11A', 'VPS33B', 'NFIX', 'PRSS1', 'BCL11A', 'TRIP12', 'EDA',
#        'GATAD2B', 'OTX2', 'CHD8', 'FOXL2', 'NAA10', 'HNF4A', 'POGZ',
#        'CLTC', 'PPM1D', 'MC4R', 'PHF6', 'KDM6A', 'DLL4', 'DCX', 'USP9X',
#        'CCM2', 'SPAG1', 'DOCK7', 'SIX3', 'WAC', 'TUBB2A', 'ADNP', 'RBM10',
#        'GRHL3', 'SON', 'NR0B1', 'TTR', 'HNF1A', 'TRPV4', 'CLCN4', 'CLCN2',
#        'TUBB2B', 'GLI2', 'FOXP3', 'CTCF', 'PDCD10', 'PAX6', 'KMT2C',
#        'TCF12', 'MYH2', 'FUCA1', 'ABCD1', 'ADA', 'TMCO1', 'CTNNB1',
#        'SHANK3', 'TNNC1', 'HSPB1', 'CAV3', 'COL9A3', 'SOX11', 'POLK',
#        'EXT1', 'RAD21', 'CACNA1C', 'KDM5C', 'PRPH2', 'SMC3', 'KAT6A',
#        'PSEN1', 'LRP6', 'G6PD', 'EFTUD2', 'PHEX', 'NIPBL', 'GALT', 'EXT2',
#        'CYP27A1', 'GLUD1', 'IRF6', 'KCNH1', 'TMEM216', 'ASXL3', 'GBA',
#        'F9', 'ASXL1', 'ELANE', 'LZTR1', 'KMT2B', 'MAP2K1', 'SMCHD1',
#        'PRPF31', 'ACTN2', 'SMARCA2', 'SATB2', 'FOXG1', 'RAD50', 'CREBBP',
#        'COL1A1', 'SYNE1', 'EP300', 'CDKN2A', 'MTOR', 'KMT2D', 'PKD2',
#        'ATP7A', 'NKX2-1', 'EEF1A2', 'EIF2B5', 'BARD1', 'F8', 'SRCAP',
#        'RNASEH2B', 'CDK13', 'KMT2A', 'ACTG1', 'CACNA1F', 'OCRL', 'CD40LG',
#        'TINF2', 'TRIO', 'MCPH1', 'ARID1A', 'GPR143', 'BEST1', 'EYA1',
#        'MEF2C', 'DNM1', 'OTC', 'SDHD', 'PDHA1', 'SCN1B', 'MIB1', 'TNNT2',
#        'FBN1', 'ANKRD11', 'MPZ', 'ABCC9', 'HNRNPU', 'RAF1', 'HDAC8',
#        'PEX7', 'ABCC2', 'PTS', 'COL4A5', 'SGSH', 'KCNH2', 'WDR62',
#        'TTC21B', 'TPM3', 'GCDH', 'DVL1', 'ATP2A2', 'ARX', 'RPGR', 'PHKA2',
#        'LDLR', 'BICD2', 'GJB2', 'CTC1', 'PCDH19', 'COL2A1', 'CUL4B',
#        'GATA6', 'EPCAM', 'RIT1', 'C19orf12', 'RP2', 'CLN8', 'DMD',
#        'TUBB8', 'CUBN', 'CHM', 'CASK', 'KAT6B', 'SYNGAP1', 'DNMT3A',
#        'FZD4', 'WAS', 'HIVEP2', 'FGD1', 'RASA1', 'AVPR2', 'PKD1', 'CRB1',
#        'PYGM', 'MEN1', 'GNE', 'HGD', 'RERE', 'POLR1C', 'MTM1', 'PRRT2',
#        'WDR45', 'FOXC1', 'CYP1B1', 'JAG1', 'HUWE1', 'SGCA', 'MAGEL2',
#        'PIGO', 'CHD7', 'PAH', 'TK2', 'DNM2', 'MYL2', 'SRD5A2', 'FGFR1',
#        'ETFDH', 'GABRB3', 'NF1', 'EZH2', 'BRAF', 'SERAC1', 'RB1', 'HNF1B',
#        'PQBP1', 'DGUOK', 'ATRX', 'PIK3R2', 'ATP1A3', 'MYH3', 'RAD51D',
#        'MFN2', 'ATL1', 'SETD2', 'FH', 'AHDC1', 'ARID1B', 'SKI', 'KCNT1',
#        'TUBA1A', 'ZNF469', 'PKP2', 'L1CAM', 'ALS2', 'DKC1', 'NF2',
#        'UNC13D', 'BMPR1A', 'MECP2', 'GCK', 'TWIST1', 'CLCN5', 'ALDH3A2',
#        'OPHN1', 'CD36', 'PAX3', 'TP53', 'CAMTA1', 'WFS1', 'COL4A1',
#        'UBE3A', 'SPRED1', 'SCN8A', 'TMPRSS3', 'KRIT1', 'ADCY5', 'RPS6KA3',
#        'PTEN', 'PEX6', 'REEP1', 'MAP2K2', 'CDKL5', 'NOTCH2', 'AR',
#        'MUTYH', 'EFNB1', 'TYR', 'BTD', 'CBL', 'PTPN11', 'IQSEC2', 'DSG2',
#        'GJA1', 'SCN1A', 'IQCB1', 'ENG', 'OPA1', 'COMP', 'DYRK1A', 'PLEC',
#        'SERPINA1', 'PLCB4', 'MLH1', 'PALB2', 'ABCC6', 'SOS1', 'NOTCH3',
#        'ADAMTSL4', 'HRAS', 'CYBB', 'WNT10A', 'ACADVL', 'TULP1', 'CLRN1',
#        'AUTS2', 'SMARCE1', 'TGM1', 'LGI1', 'HBA2', 'MYBPC3', 'DICER1',
#        'MYO7A', 'DSP', 'KRT5', 'TCOF1', 'MAN2B1', 'ACVRL1', 'RAI1', 'ELN',
#        'DYNC1H1', 'OFD1', 'POLR3B', 'FLCN', 'MYT1L', 'NR2F1', 'HPS1',
#        'MSH6', 'GRIN2B', 'SPTA1', 'SMAD3', 'PIK3CA', 'RP1', 'MED12',
#        'ARSE', 'SMARCB1', 'LMX1B', 'TP63', 'CAPN3', 'ZIC2', 'KCNQ1',
#        'TMEM67', 'IDS', 'MFRP', 'RAG1', 'USH2A', 'OTOG', 'RECQL4',
#        'COL17A1', 'STRC', 'GFAP', 'BCOR', 'MBD5', 'SDHB', 'BRCA2',
#        'DEPDC5', 'SCN5A', 'SLC6A1', 'GLB1', 'NR3C2', 'RSPH1', 'TREX1',
#        'LAMP2', 'BAP1', 'CDH1', 'SLC9A6', 'APC', 'GABRA1', 'TNFRSF1A',
#        'COL5A1', 'ABCB11', 'KRAS', 'BRCA1', 'FLNC', 'CLCN1', 'KCNQ2',
#        'GAMT', 'SDHC', 'ACADM', 'GRN', 'AIFM1', 'DNAI2', 'SGCB', 'AGPAT2',
#        'LMNA', 'STK11', 'SLC20A2', 'DNM1L', 'NHS', 'ZEB2', 'EHMT1',
#        'SLC22A5', 'OTOGL', 'CLN5', 'ATP7B', 'CPT1A', 'CP', 'CENPJ',
#        'CLN6', 'CYLD', 'SCN2A', 'NRAS', 'SLC6A8', 'PMS2', 'NSD1', 'KCNB1',
#        'COL5A2', 'WT1', 'FBN2', 'PAFAH1B1', 'F11', 'KCNQ4', 'ABCC8',
#        'IDUA', 'CBS', 'STRA6', 'CYP11B1', 'MPL', 'COL4A4', 'STXBP1',
#        'MSH2', 'INPP5E', 'SUFU', 'TGFB2', 'KRT1', 'FLNA', 'TYRP1',
#        'RARS2', 'OTOF', 'SLC2A1', 'CACNA1A', 'SMARCA4', 'PLA2G6', 'SOX9',
#        'GAA', 'KIF7', 'SLC12A6', 'MYO15A', 'SLC26A4', 'TGFBR2', 'TSC2',
#        'SLC52A2', 'TMEM127', 'DNAI1', 'AGA', 'PAX2', 'BMPR2', 'VHL',
#        'ALPL', 'BRIP1', 'ATM', 'ARSB', 'FANCC', 'DLD', 'CASR', 'DYSF',
#        'TTN', 'GDAP1', 'SLC17A5', 'XPC', 'MYLK', 'GLI3', 'SMAD4', 'RYR1',
#        'NPHS1', 'GALC', 'RYR2', 'TSC1', 'DES', 'AP4M1', 'CPT2', 'CDH23',
#        'CFTR', 'PRKAR1A', 'IGHMBP2', 'CHEK2', 'ASPM', 'MITF', 'RET',
#        'FGFR2', 'VWF', 'AAAS', 'TBX5', 'BAG3', 'PMP22', 'MKS1', 'NPC1',
#        'PNKP', 'FLG', 'LRP5', 'ADAR', 'FKRP', 'POMT1', 'NEFL', 'CC2D2A',
#        'ABCA4', 'SERPING1', 'GABRG2', 'ADSL', 'PCCB', 'MLC1', 'EARS2',
#        'KIF11', 'PDX1', 'TRIM32', 'GPC3', 'GRIN2A', 'PPT1', 'CACNA1E',
#        'DHCR7', 'SPINK5', 'TGFBR1', 'RAD51C', 'NKX2-5', 'MYH7', 'FOXP1',
#        'KANSL1', 'SPAST', 'WRN', 'SDHA', 'FIG4', 'RHO', 'LIG4', 'BTK',
#        'RSPH4A', 'NTRK1', 'NR2E3', 'DGAT1', 'CHD2', 'BBS10', 'DUOX2',
#        'CDK5RAP2', 'EYA4', 'PTCH1', 'FN1', 'ACTA2', 'NAGLU', 'HEXB',
#        'ECEL1', 'COL3A1', 'ALMS1', 'SACS', 'TRPS1', 'POMT2', 'ZFYVE26',
#        'KRT16', 'AGL', 'KCNJ11', 'LRBA', 'COL6A3', 'PCDH15', 'FAH',
#        'BBS12', 'DNAH5', 'PEX1', 'GRIN1', 'HSD17B4', 'AHI1', 'VPS13B',
#        'COL6A2', 'NBN', 'VCP', 'TCF4', 'SURF1', 'ATP6V1B1', 'NOTCH1',
#        'SPTB', 'MYH9', 'DNAH11', 'IVD', 'ARMC4', 'APOB', 'DSC2',
#        'ALDH7A1', 'LAMA2', 'AXIN2', 'NBAS', 'MVK', 'SCN4A', 'SPG11',
#        'CYP21A2', 'PCSK9', 'HBB', 'PMM2', 'MCCC1', 'UBE3B', 'MED13L',
#        'CASQ2', 'PDE6B', 'NGLY1', 'PKHD1', 'RBM20', 'ATP1A2', 'SETBP1',
#        'KIF1A', 'SLC19A3', 'HADHA', 'COLQ', 'TRAPPC11', 'TPP1', 'SMPD1',
#        'DST', 'RPGRIP1L', 'CNTNAP2', 'ALG1', 'TCTN2', 'PRKAG2', 'COL6A1',
#        'GLDC', 'ATP6V0A4', 'PCNT', 'VPS13A', 'POLG', 'KIT', 'GATA3',
#        'GCH1', 'CEP152', 'ALPK3', 'EYS', 'ATP13A2', 'CCDC40', 'BRAT1',
#        'HGSNAT', 'ERCC6', 'BLM', 'SLC26A2', 'NEB', 'CLN3', 'KCNQ3',
#        'COL11A2', 'COL1A2', 'BBS2', 'GNAS', 'GYS2', 'TSEN54', 'FANCA',
#        'LOXHD1', 'COL7A1', 'TH', 'NPHP4', 'PCCA', 'ARSA', 'KIF5A',
#        'SLC4A1', 'CPS1', 'TNXB', 'FGFR3', 'SETX', 'LYST', 'WWOX', 'XRCC2',
#        'CDKN1C', 'MEFV', 'SALL4', 'RRM2B', 'AARS2', 'KIAA0586', 'HEXA',
#        'CCDC39', 'FREM1', 'FKTN', 'RTEL1', 'COL11A1', 'LRP2', 'CEP290',
#        'HSPG2', 'ANO5', 'GAN', 'EVC2', 'PIEZO2', 'SALL1', 'FUS',
#        'TUBGCP6', 'DOCK8', 'EPG5', 'SPG7', 'GATA2', 'SH3TC2', 'RELN',
#        'FRAS1', 'ALDOB', 'AIRE', 'CHRNE', 'RAG2', 'ABCA12', 'CTNS',
#        'PEX10', 'RPE65', 'ESCO2', 'SGCG', 'SLC25A15', 'PKLR', 'DARS2',
#        'OAT', 'GMPPB', 'HIBCH', 'NDUFV1', 'BBS7', 'PHGDH', 'SLC25A20',
#        'ANK1', 'PRX', 'GNPTG', 'SBDS', 'G6PC', 'TTPA', 'GUCY2D', 'SOD1',
#        'MTHFD1', 'NALCN', 'SEC23B', 'SLC12A3', 'PANK2', 'ASL', 'ASNS',
#        'TNNI3', 'MMACHC', 'LPL', 'PYCR1', 'TYMP', 'NDUFS1', 'NR5A1',
#        'WDR19', 'GNRHR', 'ECHS1', 'CYP7B1', 'ACAT1', 'XPA', 'ASS1',
#        'MMAA', 'CRB2', 'JAK3', 'TPO', 'BBS9', 'CNGA3', 'MMAB', 'BCKDHB',
#        'LAMB3', 'ALDH5A1', 'PIK3R1', 'ERCC2', 'KRT14', 'SMARCAL1',
#        'RPGRIP1', 'CNGB3'], dtype=object)

# %%
# Same as codeblock above, but now without genes that do not have an AUC.

temp2 = test_filter1[test_filter1['auc'].notnull()]
temp2.sort_values(by=['auc'],ascending=True)['gene'].unique()
# Out:
# array(['ARID2', 'EBF3', 'RPL5', 'DDX3X', 'ZMYND11', 'PHIP', 'PUF60',
#        'PDE11A', 'VPS33B', 'NFIX', 'PRSS1', 'BCL11A', 'TRIP12', 'EDA',
#        'GATAD2B', 'OTX2', 'CHD8', 'FOXL2', 'NAA10', 'HNF4A', 'POGZ',
#        'CLTC', 'PPM1D', 'MC4R', 'PHF6', 'KDM6A', 'DLL4', 'DCX', 'USP9X',
#        'CCM2', 'SPAG1', 'DOCK7', 'SIX3', 'WAC', 'TUBB2A', 'ADNP', 'RBM10',
#        'GRHL3', 'SON', 'NR0B1', 'TTR', 'HNF1A', 'TRPV4', 'CLCN4', 'CLCN2',
#        'TUBB2B', 'GLI2', 'FOXP3', 'CTCF', 'PDCD10', 'PAX6', 'KMT2C',
#        'TCF12', 'MYH2', 'FUCA1', 'ABCD1', 'ADA', 'TMCO1', 'CTNNB1',
#        'SHANK3', 'TNNC1', 'HSPB1', 'CAV3', 'COL9A3', 'SOX11', 'POLK',
#        'EXT1', 'RAD21', 'CACNA1C', 'KDM5C', 'PRPH2', 'SMC3', 'KAT6A',
#        'PSEN1', 'LRP6', 'G6PD', 'EFTUD2', 'PHEX', 'NIPBL', 'GALT', 'EXT2',
#        'CYP27A1', 'GLUD1', 'IRF6', 'KCNH1', 'TMEM216', 'ASXL3', 'GBA',
#        'F9', 'ASXL1', 'ELANE', 'LZTR1', 'KMT2B', 'MAP2K1', 'SMCHD1',
#        'PRPF31', 'ACTN2', 'SMARCA2', 'SATB2', 'FOXG1', 'RAD50', 'CREBBP',
#        'COL1A1', 'SYNE1', 'EP300', 'CDKN2A', 'MTOR', 'KMT2D', 'PKD2',
#        'ATP7A', 'NKX2-1', 'EEF1A2', 'EIF2B5', 'BARD1', 'F8', 'SRCAP',
#        'RNASEH2B', 'CDK13', 'KMT2A', 'ACTG1', 'CACNA1F', 'OCRL', 'CD40LG',
#        'TINF2', 'TRIO', 'MCPH1', 'ARID1A', 'GPR143', 'BEST1', 'EYA1',
#        'MEF2C', 'DNM1', 'OTC', 'SDHD', 'PDHA1', 'SCN1B', 'MIB1', 'TNNT2',
#        'FBN1', 'ANKRD11', 'MPZ', 'ABCC9', 'HNRNPU', 'RAF1', 'HDAC8',
#        'PEX7', 'ABCC2', 'PTS', 'COL4A5', 'SGSH', 'KCNH2', 'WDR62',
#        'TTC21B', 'TPM3', 'GCDH', 'DVL1', 'ATP2A2', 'ARX', 'RPGR', 'PHKA2',
#        'LDLR', 'BICD2', 'GJB2', 'CTC1', 'PCDH19', 'COL2A1', 'CUL4B',
#        'GATA6', 'EPCAM', 'RIT1', 'C19orf12', 'RP2', 'CLN8', 'DMD',
#        'TUBB8', 'CUBN', 'CHM', 'CASK', 'KAT6B', 'SYNGAP1', 'DNMT3A',
#        'FZD4', 'WAS', 'HIVEP2', 'FGD1', 'RASA1', 'AVPR2', 'PKD1', 'CRB1',
#        'PYGM', 'MEN1', 'GNE', 'HGD', 'RERE', 'POLR1C', 'MTM1', 'PRRT2',
#        'WDR45', 'FOXC1', 'CYP1B1', 'JAG1', 'HUWE1', 'SGCA', 'MAGEL2',
#        'PIGO', 'CHD7', 'PAH', 'TK2', 'DNM2', 'MYL2', 'SRD5A2', 'FGFR1',
#        'ETFDH', 'GABRB3', 'NF1', 'EZH2', 'BRAF', 'SERAC1', 'RB1', 'HNF1B',
#        'PQBP1', 'DGUOK', 'ATRX', 'PIK3R2', 'ATP1A3', 'MYH3', 'RAD51D',
#        'MFN2', 'ATL1', 'SETD2', 'FH', 'AHDC1', 'ARID1B', 'SKI', 'KCNT1',
#        'TUBA1A', 'ZNF469', 'PKP2', 'L1CAM', 'ALS2', 'DKC1', 'NF2',
#        'UNC13D', 'BMPR1A', 'MECP2', 'GCK', 'TWIST1', 'CLCN5', 'ALDH3A2',
#        'OPHN1', 'CD36', 'PAX3', 'TP53', 'CAMTA1', 'WFS1', 'COL4A1',
#        'UBE3A', 'SPRED1', 'SCN8A', 'TMPRSS3', 'KRIT1', 'ADCY5', 'RPS6KA3',
#        'PTEN', 'PEX6', 'REEP1', 'MAP2K2', 'CDKL5', 'NOTCH2', 'AR',
#        'MUTYH', 'EFNB1', 'TYR', 'BTD', 'CBL', 'PTPN11', 'IQSEC2', 'DSG2',
#        'GJA1', 'SCN1A', 'IQCB1', 'ENG', 'OPA1', 'COMP', 'DYRK1A', 'PLEC',
#        'SERPINA1', 'PLCB4', 'MLH1', 'PALB2', 'ABCC6', 'SOS1', 'NOTCH3',
#        'ADAMTSL4', 'HRAS', 'CYBB', 'WNT10A', 'ACADVL', 'TULP1', 'CLRN1',
#        'AUTS2', 'SMARCE1', 'TGM1', 'LGI1', 'HBA2', 'MYBPC3', 'DICER1',
#        'MYO7A', 'DSP', 'KRT5', 'TCOF1', 'MAN2B1', 'ACVRL1', 'RAI1', 'ELN',
#        'DYNC1H1', 'OFD1', 'POLR3B', 'FLCN', 'MYT1L', 'NR2F1', 'HPS1',
#        'MSH6', 'GRIN2B', 'SPTA1', 'SMAD3', 'PIK3CA', 'RP1', 'MED12',
#        'ARSE', 'SMARCB1', 'LMX1B', 'TP63', 'CAPN3', 'ZIC2', 'KCNQ1',
#        'TMEM67', 'IDS', 'MFRP', 'RAG1', 'USH2A', 'OTOG', 'RECQL4',
#        'COL17A1', 'STRC', 'GFAP', 'BCOR', 'MBD5', 'SDHB', 'BRCA2',
#        'DEPDC5', 'SCN5A', 'SLC6A1', 'GLB1', 'NR3C2', 'RSPH1', 'TREX1',
#        'LAMP2', 'BAP1', 'CDH1', 'SLC9A6', 'APC', 'GABRA1', 'TNFRSF1A',
#        'COL5A1', 'ABCB11', 'KRAS', 'BRCA1', 'FLNC', 'CLCN1', 'KCNQ2',
#        'GAMT', 'SDHC', 'ACADM', 'GRN', 'AIFM1', 'DNAI2', 'SGCB', 'AGPAT2',
#        'LMNA', 'STK11', 'SLC20A2', 'DNM1L', 'NHS', 'ZEB2', 'EHMT1',
#        'SLC22A5', 'OTOGL', 'CLN5', 'ATP7B', 'CPT1A', 'CP', 'CENPJ',
#        'CLN6', 'CYLD', 'SCN2A', 'NRAS', 'SLC6A8', 'PMS2', 'NSD1', 'KCNB1',
#        'COL5A2', 'WT1', 'FBN2', 'PAFAH1B1', 'F11', 'KCNQ4', 'ABCC8',
#        'IDUA', 'CBS', 'STRA6', 'CYP11B1', 'MPL', 'COL4A4', 'STXBP1',
#        'MSH2', 'INPP5E', 'SUFU', 'TGFB2', 'KRT1', 'FLNA', 'TYRP1',
#        'RARS2', 'OTOF', 'SLC2A1', 'CACNA1A', 'SMARCA4', 'PLA2G6', 'SOX9',
#        'GAA', 'KIF7', 'SLC12A6', 'MYO15A', 'SLC26A4', 'TGFBR2', 'TSC2',
#        'SLC52A2', 'TMEM127', 'DNAI1', 'AGA', 'PAX2', 'BMPR2', 'VHL',
#        'ALPL', 'BRIP1', 'ATM', 'ARSB', 'FANCC', 'DLD', 'CASR', 'DYSF',
#        'TTN', 'GDAP1', 'SLC17A5', 'XPC', 'MYLK', 'GLI3', 'SMAD4', 'RYR1',
#        'NPHS1', 'GALC', 'RYR2', 'TSC1', 'DES', 'AP4M1', 'CPT2', 'CDH23',
#        'CFTR', 'PRKAR1A', 'IGHMBP2', 'CHEK2', 'ASPM', 'MITF', 'RET',
#        'FGFR2', 'VWF', 'AAAS', 'TBX5', 'BAG3', 'PMP22', 'MKS1', 'NPC1',
#        'PNKP', 'FLG', 'LRP5', 'ADAR', 'FKRP', 'POMT1', 'NEFL', 'CC2D2A',
#        'ABCA4', 'SERPING1', 'GABRG2', 'ADSL', 'PCCB', 'MLC1', 'EARS2',
#        'KIF11', 'PDX1', 'TRIM32', 'GPC3', 'GRIN2A', 'PPT1', 'CACNA1E',
#        'DHCR7', 'SPINK5', 'TGFBR1', 'RAD51C', 'NKX2-5', 'MYH7', 'FOXP1',
#        'KANSL1', 'SPAST', 'WRN', 'SDHA', 'FIG4', 'RHO', 'LIG4', 'BTK',
#        'RSPH4A', 'NTRK1', 'NR2E3', 'DGAT1', 'CHD2', 'BBS10', 'DUOX2',
#        'CDK5RAP2', 'EYA4', 'PTCH1', 'FN1', 'ACTA2', 'NAGLU', 'HEXB',
#        'ECEL1', 'COL3A1', 'ALMS1', 'SACS', 'TRPS1', 'POMT2', 'ZFYVE26',
#        'KRT16', 'AGL', 'KCNJ11', 'LRBA', 'COL6A3', 'PCDH15', 'FAH',
#        'BBS12', 'DNAH5', 'PEX1', 'GRIN1', 'HSD17B4', 'AHI1', 'VPS13B',
#        'COL6A2', 'NBN', 'VCP', 'TCF4', 'SURF1', 'ATP6V1B1', 'NOTCH1',
#        'SPTB', 'MYH9', 'DNAH11', 'IVD', 'ARMC4', 'APOB', 'DSC2',
#        'ALDH7A1', 'LAMA2', 'AXIN2', 'NBAS', 'MVK', 'SCN4A', 'SPG11',
#        'CYP21A2', 'PCSK9', 'HBB', 'PMM2', 'MCCC1', 'UBE3B', 'MED13L',
#        'CASQ2', 'PDE6B', 'NGLY1', 'PKHD1', 'RBM20', 'ATP1A2', 'SETBP1',
#        'KIF1A', 'SLC19A3', 'HADHA', 'COLQ', 'TRAPPC11', 'TPP1', 'SMPD1',
#        'DST', 'RPGRIP1L', 'CNTNAP2', 'ALG1', 'TCTN2', 'PRKAG2', 'COL6A1',
#        'GLDC', 'ATP6V0A4', 'PCNT', 'VPS13A', 'POLG', 'KIT', 'GATA3',
#        'GCH1', 'CEP152', 'ALPK3', 'EYS', 'ATP13A2', 'CCDC40', 'BRAT1',
#        'HGSNAT', 'ERCC6', 'BLM', 'SLC26A2', 'NEB', 'CLN3', 'KCNQ3',
#        'COL11A2', 'COL1A2', 'BBS2', 'GNAS', 'GYS2', 'TSEN54', 'FANCA',
#        'LOXHD1', 'COL7A1', 'TH', 'NPHP4', 'PCCA', 'ARSA', 'KIF5A',
#        'SLC4A1', 'CPS1', 'TNXB', 'FGFR3', 'SETX', 'LYST', 'WWOX', 'XRCC2',
#        'CDKN1C', 'MEFV', 'SALL4', 'RRM2B', 'AARS2', 'KIAA0586', 'HEXA',
#        'CCDC39', 'FREM1', 'FKTN', 'RTEL1', 'COL11A1', 'LRP2', 'CEP290',
#        'HSPG2', 'ANO5', 'GAN', 'EVC2', 'PIEZO2', 'SALL1', 'FUS',
#        'TUBGCP6', 'DOCK8', 'EPG5', 'SPG7', 'GATA2', 'SH3TC2', 'RELN',
#        'FRAS1', 'ALDOB', 'AIRE', 'CHRNE', 'RAG2', 'ABCA12', 'CTNS',
#        'PEX10', 'RPE65', 'ESCO2', 'SGCG', 'SLC25A15', 'PKLR', 'DARS2',
#        'OAT', 'GMPPB', 'HIBCH', 'NDUFV1', 'BBS7', 'PHGDH', 'SLC25A20',
#        'ANK1', 'PRX', 'GNPTG', 'SBDS', 'G6PC', 'TTPA', 'GUCY2D', 'SOD1',
#        'MTHFD1', 'NALCN', 'SEC23B', 'SLC12A3', 'PANK2', 'ASL', 'ASNS',
#        'TNNI3', 'MMACHC', 'LPL', 'PYCR1', 'TYMP', 'NDUFS1', 'NR5A1',
#        'WDR19', 'GNRHR', 'ECHS1', 'CYP7B1', 'ACAT1', 'XPA', 'ASS1',
#        'MMAA', 'CRB2', 'JAK3', 'TPO', 'BBS9', 'CNGA3', 'MMAB', 'BCKDHB',
#        'LAMB3', 'ALDH5A1', 'PIK3R1', 'ERCC2', 'KRT14', 'SMARCAL1',
#        'RPGRIP1', 'CNGB3'], dtype=object)

# %%
# PHIP might be interesting.

temp2[temp2['gene'] == 'PHIP']
# Out:
#      #Chrom       Pos             Ref  Alt    max_AF  Consequence label  \
# 6277      6  79707979               A    T  0.000004  STOP_GAINED  LB/B
# 6278      6  79656530               G    C  0.000000  STOP_GAINED  LB/B
# 6279      6  79752583               G    A  0.000000  STOP_GAINED  LB/B
# 6280      6  79724886              AG    A  0.000009  FRAME_SHIFT  LB/B
# 6281      6  79655803              TG    T  0.000009  FRAME_SHIFT  LB/B
# 6282      6  79724881             ACT    A  0.000009  FRAME_SHIFT  LB/B
# 6283      6  79707130  CCTGGCTACACCAG    C  0.000009  FRAME_SHIFT  LB/B
# 6284      6  79655915             AAT    A  0.000000  FRAME_SHIFT  LP/P
# 6285      6  79692624           CTTCT    C  0.000000  FRAME_SHIFT  LP/P
# 6286      6  79700682               G  GTC  0.000000  FRAME_SHIFT  LP/P
# 6287      6  79679595              CA    C  0.000000  FRAME_SHIFT  LP/P
#
#       revel  clinpred  sift  provean  PHRED  fathmm_score    capice  ponp2  \
# 6277    NaN       NaN   NaN      NaN   39.0      0.071601  0.908600    NaN
# 6278    NaN       NaN   NaN      NaN   43.0           NaN  0.405693    NaN
# 6279    NaN       NaN   NaN      NaN   37.0           NaN  0.900301    NaN
# 6280    NaN       NaN   NaN      NaN   35.0           NaN  0.725935    NaN
# 6281    NaN       NaN   NaN      NaN   27.8           NaN  0.914858    NaN
# 6282    NaN       NaN   NaN      NaN   34.0           NaN  0.577542    NaN
# 6283    NaN       NaN   NaN      NaN   34.0           NaN  0.808567    NaN
# 6284    NaN       NaN   NaN      NaN   33.0           NaN  0.859248    NaN
# 6285    NaN       NaN   NaN      NaN   34.0           NaN  0.807910    NaN
# 6286    NaN       NaN   NaN      NaN   35.0           NaN  0.135553    NaN
# 6287    NaN       NaN   NaN      NaN   35.0           NaN  0.956974    NaN
#
#       gene       auc exonic  n_test  n_test_malign
# 6277  PHIP  0.714286      0      59             17
# 6278  PHIP  0.714286      0      59             17
# 6279  PHIP  0.714286      0      59             17
# 6280  PHIP  0.714286      0      59             17
# 6281  PHIP  0.714286      0      59             17
# 6282  PHIP  0.714286      0      59             17
# 6283  PHIP  0.714286      0      59             17
# 6284  PHIP  0.714286      0      59             17
# 6285  PHIP  0.714286      0      59             17
# 6286  PHIP  0.714286      0      59             17
# 6287  PHIP  0.714286      0      59             17

# %%
# Some plotting of Z-scores of the AUC and the number of malignant train samples.
temp2_plot = calc_z_scores(np.array(temp2[['auc','n_test_malign']].sort_values(by=['n_test_malign'], ascending=False)))
temp2_plot_index = np.arange(temp2_plot.shape[0])
plt.plot(temp2_plot_index, temp2_plot[:,0], label='auc')
plt.plot(temp2_plot_index, temp2_plot[:,1], label='n_test_malignant')
plt.legend()
plt.show()

# %%
# Applying labels.
iedsdl = intronic_exonic_dataset.copy()
iedsdl['label'] = iedsdl['label'].replace({"LB/B":0,"LP/P":1})
iedsdl
# Out:
#       #Chrom       Pos      Ref Alt    max_AF       Consequence  label  revel  \
# 0         21  33974174        C   G  0.000058         STOP_LOST      0    NaN
# 1         21  33974278        C  CA  0.000045       FRAME_SHIFT      0    NaN
# 2          X  99661625        G   C  0.000037        SYNONYMOUS      0    NaN
# 3          X  99663098        G  GT  0.000013       STOP_GAINED      0    NaN
# 4          X  99662275        C   G  0.000212    NON_SYNONYMOUS      0  0.527
# ...      ...       ...      ...  ..       ...               ...    ...    ...
# 10540     22  36662041  AATAATT   A  0.141400           INFRAME      1    NaN
# 10541      2  31754497        T   C  0.000033  NONCODING_CHANGE      1    NaN
# 10542      2  31754393        C   T  0.000000  NONCODING_CHANGE      1    NaN
# 10543      2  31758741        T   C  0.000200  NONCODING_CHANGE      1    NaN
# 10544     16    223597        T   C  0.001252         STOP_LOST      1    NaN
#
#        clinpred  sift  provean   PHRED  fathmm_score    capice  ponp2  \
# 0           NaN   NaN      NaN  15.050           NaN  0.003275    NaN
# 1           NaN   NaN      NaN  35.000           NaN  0.304741    NaN
# 2           NaN  0.00    -0.00   0.806           NaN  0.000075    NaN
# 3           NaN   NaN      NaN  35.000           NaN  0.998694    NaN
# 4           NaN  0.95     2.51  27.000           NaN  0.863940  0.436
# ...         ...   ...      ...     ...           ...       ...    ...
# 10540       NaN   NaN     8.98   7.508           NaN  0.004829    NaN
# 10541       NaN   NaN      NaN  19.790      0.951270  0.918898    NaN
# 10542       NaN   NaN      NaN  21.700           NaN  0.985064    NaN
# 10543       NaN   NaN      NaN  20.800      0.912937  0.474717    NaN
# 10544       NaN   NaN      NaN  18.020           NaN  0.971616    NaN
#
#            gene       auc  exonic  n_test  n_test_malign
# 0      C21orf59       NaN       1    19.0            0.0
# 1      C21orf59       NaN       1    19.0            0.0
# 2        PCDH19  0.906593       1   177.0           86.0
# 3        PCDH19  0.906593       1   177.0           86.0
# 4        PCDH19  0.906593       1   177.0           86.0
# ...         ...       ...     ...     ...            ...
# 10540     APOL1       NaN       1    81.0            0.0
# 10541    SRD5A2  0.921053       0    30.0           19.0
# 10542    SRD5A2  0.921053       0    30.0           19.0
# 10543    SRD5A2  0.921053       0    30.0           19.0
# 10544      HBA2  0.937500       1    26.0           18.0
#
# [10545 rows x 20 columns]

# %%
# Some more plotting of the data, might actually be a duplicate.

tot_malign = iedsdl['n_test_malign'].sum()
iedsdl_malign = iedsdl[iedsdl['label'] == 1]
iedsdl_benign = iedsdl[iedsdl['label'] == 0]
fig = plt.figure(figsize=(20,15), dpi=50)
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.scatter(iedsdl_malign['capice'], iedsdl_malign['n_test_malign'], c='red', label='Malign, test malign', s=1)
axes.scatter(iedsdl_benign['capice'], iedsdl_benign['n_test_malign'], c='blue', label='Benign, test malign', s=1)
# axes.scatter(iedsdl_malign['capice'], iedsdl_malign['n_test'], c='purple', label='Malign, full', s=1)
# axes.scatter(iedsdl_benign['capice'], iedsdl_benign['n_test'], c='orange', label='Benign, full', s=1)

axes.set_xlabel("capice")
axes.set_ylabel("Number of malign test samples")
axes.set_title("Capice score vs n test samples")
axes.legend()
plt.show()

# %%
# Duplicate plots of the violinplots earlier in this notebook.

capice_per_malign = np.array(iedsdl[iedsdl['label'] == 1][['capice']])
capice_per_benign = np.array(iedsdl[iedsdl['label'] == 0][['capice']])

plt.violinplot(capice_per_malign,vert=False,showmeans=True,showextrema=True,showmedians=True)
plt.title('Malignant')
plt.xlabel('Value')
plt.ylabel("Distribution")
plt.show()
plt.violinplot(capice_per_benign,vert=False,showmeans=True,showextrema=True,showmedians=True)
plt.title('Benign')
plt.xlabel('Value')
plt.ylabel("Distribution")
plt.show()

# %%
# Some more sorting.

temp3 = iedsdl[iedsdl['n_test_malign'].notnull()]
temp3.sort_values(by=['n_test_malign'])
# Out:
#      #Chrom       Pos           Ref   Alt    max_AF  Consequence  label  \
# 0        21  33974174             C     G  0.000058    STOP_LOST      0
# 5348     20   2377257             G     A  0.000009  STOP_GAINED      0
# 5349     20   2380225             C     T  0.000144  STOP_GAINED      0
# 5350     20   2377268             C     T  0.000030  STOP_GAINED      0
# 5351     20   2411129             T     A  0.000009  STOP_GAINED      0
# ...     ...       ...           ...   ...       ...          ...    ...
# 2428     13  32945164            AT     A  0.000000  FRAME_SHIFT      1
# 2427     13  32903615            CA     C  0.000000  FRAME_SHIFT      1
# 2426     13  32911661           AAG     A  0.000000  FRAME_SHIFT      1
# 3036     13  32968863             C     A  0.000000  STOP_GAINED      1
# 2589     13  32953601  ACCGTGTGGAAG  TCCC  0.000000  FRAME_SHIFT      1
#
#       revel  clinpred  sift  provean  PHRED  fathmm_score    capice  ponp2  \
# 0       NaN       NaN   NaN      NaN  15.05           NaN  0.003275    NaN
# 5348    NaN       NaN   NaN      NaN  49.00           NaN  0.088299    NaN
# 5349    NaN       NaN   NaN      NaN  37.00      0.172360  0.007464    NaN
# 5350    NaN       NaN   NaN      NaN  46.00           NaN  0.006441    NaN
# 5351    NaN       NaN   NaN      NaN  39.00      0.116146  0.008311    NaN
# ...     ...       ...   ...      ...    ...           ...       ...    ...
# 2428    NaN       NaN   NaN      NaN  26.20           NaN  0.997950    NaN
# 2427    NaN       NaN   NaN      NaN  24.80           NaN  0.999726    NaN
# 2426    NaN       NaN   NaN      NaN  25.90           NaN  0.999866    NaN
# 3036    NaN       NaN   NaN      NaN  36.00           NaN  0.886732    NaN
# 2589    NaN       NaN   NaN      NaN  35.00           NaN  0.999970    NaN
#
#           gene       auc  exonic  n_test  n_test_malign
# 0     C21orf59       NaN       1    19.0            0.0
# 5348      TGM6       NaN       1   178.0            0.0
# 5349      TGM6       NaN       1   178.0            0.0
# 5350      TGM6       NaN       1   178.0            0.0
# 5351      TGM6       NaN       1   178.0            0.0
# ...        ...       ...     ...     ...            ...
# 2428     BRCA2  0.946305       1  2973.0         1756.0
# 2427     BRCA2  0.946305       1  2973.0         1756.0
# 2426     BRCA2  0.946305       1  2973.0         1756.0
# 3036     BRCA2  0.946305       1  2973.0         1756.0
# 2589     BRCA2  0.946305       1  2973.0         1756.0
#
# [10502 rows x 20 columns]

# %%
# Gene annotation:
# Dominant/Recessief?
# Ziektebeeld (maybe)?
# Kolmogorov-Smirnov test over distributions over capice in pathogenic vs benign
# Discussie note: varianten kunnen verkeerd gelabeld zijn!
# Model getrained genoom breed, uitkijken met uitspraken over genen en varianten.
# Meer test train/test runs met extra/minder variabelen.

# %%
# Loading in the cgd database for inheritance data.

cgd_txt = pd.read_csv("/home/"+location+"/Documents/School/Master_DSLS/Final_Thesis/Initial_Data_exploration/CGD.txt", sep='\t', header=0)
cgd_txt
# Out:
#        #GENE  HGNC ID  ENTREZ GENE ID  \
# 0        A2M        7               2
# 1      A2ML1    23336          144568
# 2     A4GALT    18149           53947
# 3       AAAS    13666            8086
# 4      AAGAB    25662           79719
# ...      ...      ...             ...
# 3995  ZNHIT3    12309            9326
# 3996     ZP1    13187           22917
# 3997     ZP2    13188            7783
# 3998     ZP3    13189            7784
# 3999  ZSWIM6    29316           57688
#
#                                               CONDITION INHERITANCE  \
# 0                      Alpha-2-macroglobulin deficiency          AD
# 1                       Otitis media, susceptibility to          AD
# 2                                 Blood group, P system          BG
# 3            Achalasia-addisonianism-alacrimia syndrome          AR
# 4           Keratoderma, palmoplantar, punctate type IA          AD
# ...                                                 ...         ...
# 3995                                      PEHO syndrome          AR
# 3996                         Oocyte maturation defect 1          AR
# 3997                         Oocyte maturation defect 6          AR
# 3998                         Oocyte maturation defect 3          AD
# 3999  Acromelic frontonasal dysostosis; Neurodevelop...          AD
#
#       AGE GROUP ALLELIC CONDITIONS  \
# 0           NaN                NaN
# 1     Pediatric                NaN
# 2     Pediatric                NaN
# 3     Pediatric                NaN
# 4           NaN                NaN
# ...         ...                ...
# 3995        NaN                NaN
# 3996        NaN                NaN
# 3997        NaN                NaN
# 3998        NaN                NaN
# 3999        NaN                NaN
#
#                                MANIFESTATION CATEGORIES  \
# 0                                               General
# 1                         Allergy/Immunology/Infectious
# 2                                           Hematologic
# 3     Dermatologic; Endocrine; Gastrointestinal; Neu...
# 4                                          Dermatologic
# ...                                                 ...
# 3995             Craniofacial; Dermatologic; Neurologic
# 3996                                          Obstetric
# 3997                                          Obstetric
# 3998                                          Obstetric
# 3999          Craniofacial; Musculoskeletal; Neurologic
#
#             INTERVENTION CATEGORIES  \
# 0                           General
# 1     Allergy/Immunology/Infectious
# 2                       Hematologic
# 3                         Endocrine
# 4                           General
# ...                             ...
# 3995                        General
# 3996                        General
# 3997                        General
# 3998                        General
# 3999                        General
#
#                                                COMMENTS  \
# 0     Variants have been implicated in pulmonary dis...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3995                                                NaN
# 3996                                                NaN
# 3997                                                NaN
# 3998                                                NaN
# 3999                                                NaN
#
#                                  INTERVENTION/RATIONALE  \
# 0     The clinical consequences of variants are unclear
# 1     Individuals may have increased susceptibility ...
# 2     Variants associated with a blood group may be ...
# 3     Surveillance and treatment/preventive measures...
# 4     Genetic knowledge may be beneficial related to...
# ...                                                 ...
# 3995  Genetic knowledge may be beneficial related to...
# 3996  Genetic knowledge may be beneficial related to...
# 3997  Genetic knowledge may be beneficial related to...
# 3998  Genetic knowledge may be beneficial related to...
# 3999  Genetic knowledge may be beneficial related to...
#
#                                              REFERENCES
# 0                              94459; 2475424; 1370808
# 1                                              26121085
# 2                                              10993874
# 3     78049; 6243664; 3565479; 1537368; 8006362; 789...
# 4                                    23000146; 23064416
# ...                                                 ...
# 3995                                           28335020
# 3996                                           24670168
# 3997                                           29895852
# 3998                                           28886344
# 3999                                 25105228; 29198722
#
# [4000 rows x 12 columns]

# %%
# Merging with detailed dataset.

inheritence_ieds = pd.merge(iedsdl, cgd_txt[['#GENE','INHERITANCE','AGE GROUP']], left_on=['gene'], right_on=['#GENE'])
inheritence_ieds = inheritence_ieds.drop(['#GENE'], axis=1)
inheritence_ieds
# Out:
#      #Chrom       Pos Ref     Alt    max_AF       Consequence  label  revel  \
# 0         X  99661625   G       C  0.000037        SYNONYMOUS      0    NaN
# 1         X  99663098   G      GT  0.000013       STOP_GAINED      0    NaN
# 2         X  99662275   C       G  0.000212    NON_SYNONYMOUS      0  0.527
# 3         X  99657670   A  ACCCAG  0.000000       FRAME_SHIFT      1    NaN
# 4        17  29509638   C       T  0.000000        SYNONYMOUS      0    NaN
# ...     ...       ...  ..     ...       ...               ...    ...    ...
# 9304      X  19368150   A    AAGA  0.000000           INFRAME      1    NaN
# 9305      2  31754497   T       C  0.000033  NONCODING_CHANGE      1    NaN
# 9306      2  31754393   C       T  0.000000  NONCODING_CHANGE      1    NaN
# 9307      2  31758741   T       C  0.000200  NONCODING_CHANGE      1    NaN
# 9308     16    223597   T       C  0.001252         STOP_LOST      1    NaN
#
#       clinpred   sift  ...  fathmm_score    capice  ponp2    gene       auc  \
# 0          NaN  0.000  ...           NaN  0.000075    NaN  PCDH19  0.906593
# 1          NaN    NaN  ...           NaN  0.998694    NaN  PCDH19  0.906593
# 2          NaN  0.950  ...           NaN  0.863940  0.436  PCDH19  0.906593
# 3          NaN    NaN  ...           NaN  0.687628    NaN  PCDH19  0.906593
# 4          NaN  0.647  ...           NaN  0.001511    NaN     NF1  0.922413
# ...        ...    ...  ...           ...       ...    ...     ...       ...
# 9304       NaN    NaN  ...           NaN  0.121208    NaN   PDHA1  0.894737
# 9305       NaN    NaN  ...      0.951270  0.918898    NaN  SRD5A2  0.921053
# 9306       NaN    NaN  ...           NaN  0.985064    NaN  SRD5A2  0.921053
# 9307       NaN    NaN  ...      0.912937  0.474717    NaN  SRD5A2  0.921053
# 9308       NaN    NaN  ...           NaN  0.971616    NaN    HBA2  0.937500
#
#      exonic  n_test  n_test_malign    INHERITANCE  AGE GROUP
# 0         1   177.0           86.0             XL        NaN
# 1         1   177.0           86.0             XL        NaN
# 2         1   177.0           86.0             XL        NaN
# 3         1   177.0           86.0             XL        NaN
# 4         1  1581.0          795.0             AD  Pediatric
# ...     ...     ...            ...            ...        ...
# 9304      1    73.0           35.0             XL  Pediatric
# 9305      0    30.0           19.0             AR  Pediatric
# 9306      0    30.0           19.0             AR  Pediatric
# 9307      0    30.0           19.0             AR  Pediatric
# 9308      1    26.0           18.0  AD/AR/Digenic  Pediatric
#
# [9309 rows x 22 columns]

# %%
# Preparing the dataset for better labeling.

# AD = autosomal dominant
# AR = autosomal recessive
# XL = x linked
# Digenic = simultanious mutation in different genes
# BG = blood group
inheritence_ieds['ad'] = 0
inheritence_ieds['ar'] = 0
inheritence_ieds['xl'] = 0
inheritence_ieds['digenic'] = 0
inheritence_ieds['bg'] = 0
inheritence_ieds['INHERITANCE'] = inheritence_ieds['INHERITANCE'].replace({"XL (involving both OPN1 genes)":"XL"})

# %%
# Applying the labels of inheritance, cleaning the labels in the process.

reset_timer = time.time()
done_rows = 0
total_rows = inheritence_ieds.shape[0]
for row in inheritence_ieds.iterrows():
    time_ifl = time.time()
    if time_ifl - reset_timer > 10:
        print(f"I'm still running, done: {round(done_rows / total_rows * 100, ndigits=2)}%")
        reset_timer = time.time()
    index = row[0]
    row = row[1]
    inheritance = row['INHERITANCE'].strip()
    if isinstance(inheritance, str):
        inheritance = inheritance.split("/")
        for marker in inheritance:
            if marker == "AD":
                inheritence_ieds.loc[index, 'ad'] = 1
            if marker == "AR":
                inheritence_ieds.loc[index, 'ar'] = 1
            if marker == "XL":
                inheritence_ieds.loc[index, 'xl'] = 1
            if marker == "Digenic":
                inheritence_ieds.loc[index, 'digenic'] = 1
            if marker == "BG":
                inheritence_ieds.loc[index, 'bg'] = 1
    done_rows += 1
inheritence_ieds = inheritence_ieds.drop('INHERITANCE', axis=1)

# %%
# Did it work?

inheritence_ieds
# Out:
#      #Chrom       Pos Ref     Alt    max_AF       Consequence  label  revel  \
# 0         X  99661625   G       C  0.000037        SYNONYMOUS      0    NaN
# 1         X  99663098   G      GT  0.000013       STOP_GAINED      0    NaN
# 2         X  99662275   C       G  0.000212    NON_SYNONYMOUS      0  0.527
# 3         X  99657670   A  ACCCAG  0.000000       FRAME_SHIFT      1    NaN
# 4        17  29509638   C       T  0.000000        SYNONYMOUS      0    NaN
# ...     ...       ...  ..     ...       ...               ...    ...    ...
# 9304      X  19368150   A    AAGA  0.000000           INFRAME      1    NaN
# 9305      2  31754497   T       C  0.000033  NONCODING_CHANGE      1    NaN
# 9306      2  31754393   C       T  0.000000  NONCODING_CHANGE      1    NaN
# 9307      2  31758741   T       C  0.000200  NONCODING_CHANGE      1    NaN
# 9308     16    223597   T       C  0.001252         STOP_LOST      1    NaN
#
#       clinpred   sift  ...       auc  exonic  n_test  n_test_malign  \
# 0          NaN  0.000  ...  0.906593       1   177.0           86.0
# 1          NaN    NaN  ...  0.906593       1   177.0           86.0
# 2          NaN  0.950  ...  0.906593       1   177.0           86.0
# 3          NaN    NaN  ...  0.906593       1   177.0           86.0
# 4          NaN  0.647  ...  0.922413       1  1581.0          795.0
# ...        ...    ...  ...       ...     ...     ...            ...
# 9304       NaN    NaN  ...  0.894737       1    73.0           35.0
# 9305       NaN    NaN  ...  0.921053       0    30.0           19.0
# 9306       NaN    NaN  ...  0.921053       0    30.0           19.0
# 9307       NaN    NaN  ...  0.921053       0    30.0           19.0
# 9308       NaN    NaN  ...  0.937500       1    26.0           18.0
#
#       AGE GROUP ad  ar  xl  digenic  bg
# 0           NaN  0   0   1        0   0
# 1           NaN  0   0   1        0   0
# 2           NaN  0   0   1        0   0
# 3           NaN  0   0   1        0   0
# 4     Pediatric  1   0   0        0   0
# ...         ... ..  ..  ..      ...  ..
# 9304  Pediatric  0   0   1        0   0
# 9305  Pediatric  0   1   0        0   0
# 9306  Pediatric  0   1   0        0   0
# 9307  Pediatric  0   1   0        0   0
# 9308  Pediatric  1   1   0        1   0
#
# [9309 rows x 26 columns]

# %%
# Using the thresholds Shuang used to get a predicted pathogenic true/false for capice.

inheritence_ieds['pred_patho'] = 0
inheritence_ieds.loc[inheritence_ieds[inheritence_ieds['capice'] > 0.02].index, 'pred_patho'] = 1
inheritence_ieds[['label','capice','pred_patho']]
# Out:
#       label    capice  pred_patho
# 0         0  0.000075           0
# 1         0  0.998694           1
# 2         0  0.863940           1
# 3         1  0.687628           1
# 4         0  0.001511           0
# ...     ...       ...         ...
# 9304      1  0.121208           1
# 9305      1  0.918898           1
# 9306      1  0.985064           1
# 9307      1  0.474717           1
# 9308      1  0.971616           1
#
# [9309 rows x 3 columns]

# %%
# I might have a column problem.

inheritence_ieds.columns
# Out:
# Index(['#Chrom', 'Pos', 'Ref', 'Alt', 'max_AF', 'Consequence', 'label',
#        'revel', 'clinpred', 'sift', 'provean', 'PHRED', 'fathmm_score',
#        'capice', 'ponp2', 'gene', 'auc', 'exonic', 'n_test', 'n_test_malign',
#        'AGE GROUP', 'ad', 'ar', 'xl', 'digenic', 'bg', 'pred_patho'],
#       dtype='object')

# %% [markdown]
# # TODO 10-3-2019
# - Is intronic / exonic dataset valid?
#     - Future plan to look into
# - Merge data omim and cgd
# - GAVIN well performing genes vs CAPICE wel performing genes (or inverted)
# - Inverted CADD and CAPICE scores
# - Missing features for bad performing SNV's
# - Look into PLI genes
# - Look into genes that are not clinical
# - Gain of function dataset?
# - Transcript expression aware annotation improves rare variant discovery and interpretation (lookup)
# - Ask Patrick Deelen to add me to the FrankeSwertz research group for a presentation on the research of CAPICE.
# - Get added to GCC cluster for CAPICE data.
#     - Mail sent
# - Perform wilcoxon tests
#     - Done
# - Make planning
#
# ![Gantt](img/Gantt_Chart2.png)
#
# - Share project research proposal
# - Make Z-scores instead of log normalized high differences

# %%
# Plotting of CADD vs Capice pathogenicity predition using the thresholds Shuang used.

fig = plt.figure(figsize=(20,10), dpi=200)
axes = fig.add_axes([0.1,0.1,0.8,0.8])
inheritence_codeblock62 = inheritence_ieds.copy()
inheritence_codeblock62['cadd_b'] = 0
inheritence_codeblock62['capice_b'] = 0
inheritence_codeblock62['unanimous_cc_b'] = 0
inheritence_codeblock62.loc[
    inheritence_codeblock62[inheritence_codeblock62['PHRED'] >= 30].index, 'cadd_b'] = 1
inheritence_codeblock62.loc[
    inheritence_codeblock62[inheritence_codeblock62['capice'] >= 0.02].index, 'capice_b'] = 1
filter_capice_b = inheritence_codeblock62['capice_b'] == 1
filter_cadd_b = inheritence_codeblock62['cadd_b'] == 1
inheritence_codeblock62.loc[inheritence_codeblock62[inheritence_codeblock62.where(filter_cadd_b & filter_capice_b)['#Chrom'].notnull()].index, 'unanimous_cc_b'] = 1
inheritence_codeblock62.sort_values(by=['unanimous_cc_b'], inplace=True, ignore_index=True)
print(f"Percentage of unanimous decision making: {inheritence_codeblock62[inheritence_codeblock62['unanimous_cc_b'] == 0].shape[0] / inheritence_codeblock62.shape[0] * 100}%")
axes.scatter(inheritence_codeblock62.index, inheritence_codeblock62['cadd_b'], c='red', label='CADD')
axes.scatter(inheritence_codeblock62.index, inheritence_codeblock62['capice_b'], c='blue', label='CAPICE', s=0.5)
# axes.plot(inheritence_codeblock62.index, inheritence_codeblock62['unanimous_cc_b'], c='red', label='Unanimous')
axes.set_xlabel("SNV")
axes.set_ylabel("Patho_Predict")
axes.set_title("Pathogenicity prediction per SNV")
axes.legend()
plt.show()
# Out:
# Percentage of unanimous decision making: 51.616715006982496%

# %%
# Loading in the omim gene list and cleaning it.

test_omim = pd.read_csv("/home/"+location+"/Documents/School/Master_DSLS/Final_Thesis/Initial_Data_exploration/genemap2.txt", header=0, sep='\t', skiprows=3)
test_omim = test_omim[test_omim['Genomic Position Start'].notnull()]
test_omim['# Chromosome'] = test_omim['# Chromosome'].apply(lambda x: x.split("chr")[1])
test_omim = test_omim[['# Chromosome', 'Genomic Position Start', 'Genomic Position End', 'Gene Symbols']]
test_omim.columns = ['chr','start','end','gene']
initial_omim_list = list(test_omim['gene'].unique())
actual_omim_list = []
reset_timer = time.time()
done = 0
total = len(initial_omim_list)
for gene in initial_omim_list:
    time_fls = time.time()
    if time_fls - reset_timer > 10:
        print(f"Still processing, done: {round(done/total*100, ndigits=2)}%")
        reset_timer = time.time()
    gene_split = gene.split(", ")
    if len(gene_split) > 1:
        for g in gene_split:
            if g not in actual_omim_list:
                actual_omim_list.append(g)
    else:
        actual_omim_list += gene_split
    done += 1
# Out:
# Still processing, done: 79.53%

# %%
# Comparing it to the gene list that I currently have.

current_gene_list = list(inheritence_ieds['gene'].unique())
reset_timer = time.time()
done = 0
total = len(actual_omim_list)
in_list = 0
actually_in_dataset = []
for gene in actual_omim_list:
    time_fls = time.time()
    if time_fls - reset_timer > 10:
        print(f"Still processing, done: {round(done/total*100, ndigits=2)}%")
        reset_timer = time.time()
    if gene in current_gene_list:
        print(f"{gene} is present in the current dataset!")
        actually_in_dataset.append(gene)
        in_list += 1
    done += 1
print(f"Total percentage of OMIM loci in dataset: {round(in_list/total*100, ndigits=2)}%")
# Out:
# DVL1 is present in the current dataset!
# TMEM240 is present in the current dataset!
# SKI is present in the current dataset!
# PEX10 is present in the current dataset!
# PRDM16 is present in the current dataset!
# NPHP4 is present in the current dataset!
# PLEKHG5 is present in the current dataset!
# CAMTA1 is present in the current dataset!
# RERE is present in the current dataset!
# PIK3CD is present in the current dataset!
# KIF1B is present in the current dataset!
# MTOR is present in the current dataset!
# UBIAD1 is present in the current dataset!
# NPPA is present in the current dataset!
# MFN2 is present in the current dataset!
# AUH is present in the current dataset!
# EPHA2 is present in the current dataset!
# ATP13A2 is present in the current dataset!
# SDHB is present in the current dataset!
# PINK1 is present in the current dataset!
# DDOST is present in the current dataset!
# ALPL is present in the current dataset!
# HSPG2 is present in the current dataset!
# EPHB2 is present in the current dataset!
# KDM1A is present in the current dataset!
# HMGCL is present in the current dataset!
# FUCA1 is present in the current dataset!
# GRHL3 is present in the current dataset!
# LDLRAP1 is present in the current dataset!
# DHDDS is present in the current dataset!
# ARID1A is present in the current dataset!
# AHDC1 is present in the current dataset!
# GJB4 is present in the current dataset!
# PPT1 is present in the current dataset!
# KCNQ4 is present in the current dataset!
# ERMAP is present in the current dataset!
# SLC2A1 is present in the current dataset!
# MPL is present in the current dataset!
# PTCH2 is present in the current dataset!
# MUTYH is present in the current dataset!
# MMACHC is present in the current dataset!
# FOXE3 is present in the current dataset!
# ORC1 is present in the current dataset!
# COA7 is present in the current dataset!
# CPT2 is present in the current dataset!
# PARS2 is present in the current dataset!
# PCSK9 is present in the current dataset!
# C8A is present in the current dataset!
# HK1 is present in the current dataset!
# DOCK7 is present in the current dataset!
# ANGPTL3 is present in the current dataset!
# ALG6 is present in the current dataset!
# PGM1 is present in the current dataset!
# RPE65 is present in the current dataset!
# ACADM is present in the current dataset!
# NEXN is present in the current dataset!
# ZNF644 is present in the current dataset!
# RPL5 is present in the current dataset!
# ABCA4 is present in the current dataset!
# AGL is present in the current dataset!
# COL11A1 is present in the current dataset!
# NRAS is present in the current dataset!
# TSHB is present in the current dataset!
# CASQ2 is present in the current dataset!
# IGSF3 is present in the current dataset!
# PHGDH is present in the current dataset!
# NOTCH2 is present in the current dataset!
# PEX11B is present in the current dataset!
# GJA5 is present in the current dataset!
# TARS2 is present in the current dataset!
# ECM1 is present in the current dataset!
# ADAMTSL4 is present in the current dataset!
# ZNF687 is present in the current dataset!
# POGZ is present in the current dataset!
# FLG is present in the current dataset!
# GATAD2B is present in the current dataset!
# TPM3 is present in the current dataset!
# HAX1 is present in the current dataset!
# CHRNB2 is present in the current dataset!
# ADAR is present in the current dataset!
# KCNN3 is present in the current dataset!
# PMVK is present in the current dataset!
# GBA is present in the current dataset!
# PKLR is present in the current dataset!
# ASH1L is present in the current dataset!
# RIT1 is present in the current dataset!
# LMNA is present in the current dataset!
# NTRK1 is present in the current dataset!
# SPTA1 is present in the current dataset!
# ATP1A2 is present in the current dataset!
# COPA is present in the current dataset!
# PPOX is present in the current dataset!
# MPZ is present in the current dataset!
# SDHC is present in the current dataset!
# TMCO1 is present in the current dataset!
# CD247 is present in the current dataset!
# FMO3 is present in the current dataset!
# PIGC is present in the current dataset!
# DARS2 is present in the current dataset!
# TOR1AIP1 is present in the current dataset!
# LHX4 is present in the current dataset!
# CACNA1E is present in the current dataset!
# RNASEL is present in the current dataset!
# BAP1 is present in the current dataset!
# PRG4 is present in the current dataset!
# CFH is present in the current dataset!
# CFHR4 is present in the current dataset!
# CFHR5 is present in the current dataset!
# ASPM is present in the current dataset!
# CRB1 is present in the current dataset!
# CACNA1S is present in the current dataset!
# TNNT2 is present in the current dataset!
# REN is present in the current dataset!
# DSTYK is present in the current dataset!
# LAMB3 is present in the current dataset!
# IRF6 is present in the current dataset!
# KCNH1 is present in the current dataset!
# FLVCR1 is present in the current dataset!
# USH2A is present in the current dataset!
# TGFB2 is present in the current dataset!
# SLC30A10 is present in the current dataset!
# IARS2 is present in the current dataset!
# RAB3GAP2 is present in the current dataset!
# PSEN2 is present in the current dataset!
# GNPAT is present in the current dataset!
# TBCE is present in the current dataset!
# B3GALNT2 is present in the current dataset!
# LYST is present in the current dataset!
# ACTN2 is present in the current dataset!
# RYR2 is present in the current dataset!
# FMN2 is present in the current dataset!
# GREM2 is present in the current dataset!
# FH is present in the current dataset!
# AKT3 is present in the current dataset!
# HNRNPU is present in the current dataset!
# TPO is present in the current dataset!
# MYT1L is present in the current dataset!
# SOX11 is present in the current dataset!
# KLF11 is present in the current dataset!
# NBAS is present in the current dataset!
# APOB is present in the current dataset!
# DNMT3A is present in the current dataset!
# ASXL2 is present in the current dataset!
# HADHA is present in the current dataset!
# OTOF is present in the current dataset!
# KCNK3 is present in the current dataset!
# EBF3 is present in the current dataset!
# MPV17 is present in the current dataset!
# IFT172 is present in the current dataset!
# ALK is present in the current dataset!
# SRD5A2 is present in the current dataset!
# SPAST is present in the current dataset!
# NLRC4 is present in the current dataset!
# CYP1B1 is present in the current dataset!
# SOS1 is present in the current dataset!
# ABCG5 is present in the current dataset!
# SIX3 is present in the current dataset!
# EPCAM is present in the current dataset!
# MSH2 is present in the current dataset!
# MSH6 is present in the current dataset!
# LHCGR is present in the current dataset!
# BCL11A is present in the current dataset!
# ATR is present in the current dataset!
# GFPT1 is present in the current dataset!
# DYSF is present in the current dataset!
# EXOC6B is present in the current dataset!
# ALMS1 is present in the current dataset!
# DGUOK is present in the current dataset!
# DCTN1 is present in the current dataset!
# POLR1A is present in the current dataset!
# REEP1 is present in the current dataset!
# EIF2AK3 is present in the current dataset!
# ADRA2B is present in the current dataset!
# TMEM127 is present in the current dataset!
# SNRNP200 is present in the current dataset!
# CNGA3 is present in the current dataset!
# RANBP2 is present in the current dataset!
# EDAR is present in the current dataset!
# GLI2 is present in the current dataset!
# CXCR4 is present in the current dataset!
# KYNU is present in the current dataset!
# ZEB2 is present in the current dataset!
# ORC4 is present in the current dataset!
# MBD5 is present in the current dataset!
# KIF5C is present in the current dataset!
# NEB is present in the current dataset!
# ACVR1 is present in the current dataset!
# TBR1 is present in the current dataset!
# IFIH1 is present in the current dataset!
# SCN3A is present in the current dataset!
# SCN2A is present in the current dataset!
# TTC21B is present in the current dataset!
# SCN1A is present in the current dataset!
# SCN9A is present in the current dataset!
# ABCB11 is present in the current dataset!
# LRP2 is present in the current dataset!
# KLHL41 is present in the current dataset!
# HOXD13 is present in the current dataset!
# PDE11A is present in the current dataset!
# PRKRA is present in the current dataset!
# TTN is present in the current dataset!
# CERKL is present in the current dataset!
# NEUROD1 is present in the current dataset!
# FSIP2 is present in the current dataset!
# COL3A1 is present in the current dataset!
# COL5A2 is present in the current dataset!
# SLC40A1 is present in the current dataset!
# HIBCH is present in the current dataset!
# SATB2 is present in the current dataset!
# CASP10 is present in the current dataset!
# ALS2 is present in the current dataset!
# BMPR2 is present in the current dataset!
# CTLA4 is present in the current dataset!
# ICOS is present in the current dataset!
# NDUFS1 is present in the current dataset!
# CRYGD is present in the current dataset!
# CRYGB is present in the current dataset!
# PIKFYVE is present in the current dataset!
# CPS1 is present in the current dataset!
# ERBB4 is present in the current dataset!
# BARD1 is present in the current dataset!
# ABCA12 is present in the current dataset!
# FN1 is present in the current dataset!
# SMARCAL1 is present in the current dataset!
# CYP27A1 is present in the current dataset!
# WNT10A is present in the current dataset!
# ABCB6 is present in the current dataset!
# TUBA4A is present in the current dataset!
# DNAJB2 is present in the current dataset!
# DES is present in the current dataset!
# OBSL1 is present in the current dataset!
# PAX3 is present in the current dataset!
# CUL3 is present in the current dataset!
# COL4A4 is present in the current dataset!
# COL4A3 is present in the current dataset!
# SLC19A3 is present in the current dataset!
# TRIP12 is present in the current dataset!
# ECEL1 is present in the current dataset!
# CHRNG is present in the current dataset!
# GIGYF2 is present in the current dataset!
# KCNJ13 is present in the current dataset!
# SAG is present in the current dataset!
# COL6A3 is present in the current dataset!
# KIF1A is present in the current dataset!
# CAV3 is present in the current dataset!
# CRELD1 is present in the current dataset!
# VHL is present in the current dataset!
# RAF1 is present in the current dataset!
# WNT7A is present in the current dataset!
# TMEM43 is present in the current dataset!
# XPC is present in the current dataset!
# COLQ is present in the current dataset!
# BTD is present in the current dataset!
# NGLY1 is present in the current dataset!
# TGFBR2 is present in the current dataset!
# GLB1 is present in the current dataset!
# CRTAP is present in the current dataset!
# MLH1 is present in the current dataset!
# SCN5A is present in the current dataset!
# SCN11A is present in the current dataset!
# CTNNB1 is present in the current dataset!
# SETD2 is present in the current dataset!
# TREX1 is present in the current dataset!
# COL7A1 is present in the current dataset!
# SLC25A20 is present in the current dataset!
# NDUFAF3 is present in the current dataset!
# QRICH1 is present in the current dataset!
# GMPPB is present in the current dataset!
# DNAH1 is present in the current dataset!
# TNNC1 is present in the current dataset!
# WNT5A is present in the current dataset!
# IL17RD is present in the current dataset!
# APPL1 is present in the current dataset!
# LMOD3 is present in the current dataset!
# MITF is present in the current dataset!
# FOXP1 is present in the current dataset!
# ROBO2 is present in the current dataset!
# CHMP2B is present in the current dataset!
# ZBTB20 is present in the current dataset!
# ARHGAP31 is present in the current dataset!
# HGD is present in the current dataset!
# IQCB1 is present in the current dataset!
# CASR is present in the current dataset!
# ADCY5 is present in the current dataset!
# MYLK is present in the current dataset!
# MCM2 is present in the current dataset!
# GATA2 is present in the current dataset!
# RHO is present in the current dataset!
# ATP2C1 is present in the current dataset!
# UBA5 is present in the current dataset!
# NPHP3 is present in the current dataset!
# PCCB is present in the current dataset!
# STAG1 is present in the current dataset!
# FOXL2 is present in the current dataset!
# CP is present in the current dataset!
# CLRN1 is present in the current dataset!
# P2RY12 is present in the current dataset!
# BCHE is present in the current dataset!
# PDCD10 is present in the current dataset!
# SERPINI1 is present in the current dataset!
# PIK3CA is present in the current dataset!
# CCDC39 is present in the current dataset!
# SOX2 is present in the current dataset!
# MCCC1 is present in the current dataset!
# EIF2B5 is present in the current dataset!
# CLCN2 is present in the current dataset!
# CRYGS is present in the current dataset!
# TP63 is present in the current dataset!
# CLDN16 is present in the current dataset!
# OPA1 is present in the current dataset!
# ZNF141 is present in the current dataset!
# PDE6B is present in the current dataset!
# CPLX1 is present in the current dataset!
# IDUA is present in the current dataset!
# FGFR3 is present in the current dataset!
# SH3BP2 is present in the current dataset!
# HTT is present in the current dataset!
# MSX1 is present in the current dataset!
# EVC2 is present in the current dataset!
# WFS1 is present in the current dataset!
# HMX1 is present in the current dataset!
# CC2D2A is present in the current dataset!
# RBPJ is present in the current dataset!
# NPC1 is present in the current dataset!
# WDR19 is present in the current dataset!
# RFC1 is present in the current dataset!
# LIAS is present in the current dataset!
# CORIN is present in the current dataset!
# CNGA1 is present in the current dataset!
# SGCB is present in the current dataset!
# KIT is present in the current dataset!
# REST is present in the current dataset!
# GNRHR is present in the current dataset!
# ALB is present in the current dataset!
# FRAS1 is present in the current dataset!
# HNRNPDL is present in the current dataset!
# DSPP is present in the current dataset!
# PKD2 is present in the current dataset!
# PPP3CA is present in the current dataset!
# NFKB1 is present in the current dataset!
# TACR3 is present in the current dataset!
# CYP2U1 is present in the current dataset!
# ANK2 is present in the current dataset!
# PRSS12 is present in the current dataset!
# SEC24D is present in the current dataset!
# BBS7 is present in the current dataset!
# BBS12 is present in the current dataset!
# FAT4 is present in the current dataset!
# NAA15 is present in the current dataset!
# MMAA is present in the current dataset!
# EDNRA is present in the current dataset!
# NR3C2 is present in the current dataset!
# LRBA is present in the current dataset!
# ETFDH is present in the current dataset!
# TLL1 is present in the current dataset!
# AGA is present in the current dataset!
# TENM3 is present in the current dataset!
# TRAPPC11 is present in the current dataset!
# F11 is present in the current dataset!
# SDHA is present in the current dataset!
# SLC6A19 is present in the current dataset!
# DNAH5 is present in the current dataset!
# TRIO is present in the current dataset!
# ANKH is present in the current dataset!
# AMACR is present in the current dataset!
# NIPBL is present in the current dataset!
# C9 is present in the current dataset!
# C6 is present in the current dataset!
# GHR is present in the current dataset!
# HCN1 is present in the current dataset!
# CCNO is present in the current dataset!
# MAP3K1 is present in the current dataset!
# NDUFAF2 is present in the current dataset!
# ZSWIM6 is present in the current dataset!
# PIK3R1 is present in the current dataset!
# MARVELD2 is present in the current dataset!
# SMN1 is present in the current dataset!
# HEXB is present in the current dataset!
# GFM2 is present in the current dataset!
# AP3B1 is present in the current dataset!
# ARSB is present in the current dataset!
# MSH3 is present in the current dataset!
# VCAN is present in the current dataset!
# RASA1 is present in the current dataset!
# MEF2C is present in the current dataset!
# NR2F1 is present in the current dataset!
# PCSK1 is present in the current dataset!
# CHD1 is present in the current dataset!
# APC is present in the current dataset!
# HSD17B4 is present in the current dataset!
# LOX is present in the current dataset!
# ALDH7A1 is present in the current dataset!
# FBN2 is present in the current dataset!
# HINT1 is present in the current dataset!
# P4HA2 is present in the current dataset!
# SLC22A5 is present in the current dataset!
# RAD50 is present in the current dataset!
# PITX1 is present in the current dataset!
# TGFBI is present in the current dataset!
# HSPA9 is present in the current dataset!
# CTNNA1 is present in the current dataset!
# MATR3 is present in the current dataset!
# DIAPH1 is present in the current dataset!
# POU4F3 is present in the current dataset!
# SPINK1 is present in the current dataset!
# SPINK5 is present in the current dataset!
# SH3TC2 is present in the current dataset!
# SLC26A2 is present in the current dataset!
# CSF1R is present in the current dataset!
# PDGFRB is present in the current dataset!
# TCOF1 is present in the current dataset!
# NIPAL4 is present in the current dataset!
# GABRA1 is present in the current dataset!
# GABRG2 is present in the current dataset!
# NKX2-5 is present in the current dataset!
# MSX2 is present in the current dataset!
# GRIN1 is present in the current dataset!
# NSD1 is present in the current dataset!
# DDX41 is present in the current dataset!
# B4GALT7 is present in the current dataset!
# ADAMTS2 is present in the current dataset!
# SQSTM1 is present in the current dataset!
# FOXC1 is present in the current dataset!
# TUBB2A is present in the current dataset!
# TUBB2B is present in the current dataset!
# DSP is present in the current dataset!
# ATXN1 is present in the current dataset!
# DCDC2 is present in the current dataset!
# ALDH5A1 is present in the current dataset!
# ZFP57 is present in the current dataset!
# NEU1 is present in the current dataset!
# C2 is present in the current dataset!
# CYP21A2 is present in the current dataset!
# TNXB is present in the current dataset!
# COL11A2 is present in the current dataset!
# SYNGAP1 is present in the current dataset!
# TULP1 is present in the current dataset!
# SLC26A8 is present in the current dataset!
# TREM2 is present in the current dataset!
# PRPH2 is present in the current dataset!
# PEX6 is present in the current dataset!
# PPP2R5D is present in the current dataset!
# POLR1C is present in the current dataset!
# AARS2 is present in the current dataset!
# RUNX2 is present in the current dataset!
# PKHD1 is present in the current dataset!
# ELOVL5 is present in the current dataset!
# DST is present in the current dataset!
# EYS is present in the current dataset!
# LMBRD1 is present in the current dataset!
# RIMS1 is present in the current dataset!
# KCNQ5 is present in the current dataset!
# SLC17A5 is present in the current dataset!
# IMPG1 is present in the current dataset!
# PHIP is present in the current dataset!
# BCKDHB is present in the current dataset!
# TBX18 is present in the current dataset!
# RARS2 is present in the current dataset!
# MAP3K7 is present in the current dataset!
# FBXL4 is present in the current dataset!
# SEC63 is present in the current dataset!
# FIG4 is present in the current dataset!
# LAMA4 is present in the current dataset!
# COL10A1 is present in the current dataset!
# RSPH4A is present in the current dataset!
# GJA1 is present in the current dataset!
# LAMA2 is present in the current dataset!
# ARG1 is present in the current dataset!
# EYA4 is present in the current dataset!
# AHI1 is present in the current dataset!
# PEX7 is present in the current dataset!
# TNFAIP3 is present in the current dataset!
# HIVEP2 is present in the current dataset!
# RMND1 is present in the current dataset!
# SYNE1 is present in the current dataset!
# ARID1B is present in the current dataset!
# SERAC1 is present in the current dataset!
# ERMARD is present in the current dataset!
# TBP is present in the current dataset!
# LFNG is present in the current dataset!
# BRAT1 is present in the current dataset!
# PMS2 is present in the current dataset!
# RAC1 is present in the current dataset!
# TWIST1 is present in the current dataset!
# DNAH11 is present in the current dataset!
# HOXA13 is present in the current dataset!
# BBS9 is present in the current dataset!
# TBX20 is present in the current dataset!
# ANLN is present in the current dataset!
# CDK13 is present in the current dataset!
# GLI3 is present in the current dataset!
# GCK is present in the current dataset!
# CCM2 is present in the current dataset!
# DDC is present in the current dataset!
# EGFR is present in the current dataset!
# ASL is present in the current dataset!
# SBDS is present in the current dataset!
# ELN is present in the current dataset!
# HSPB1 is present in the current dataset!
# CD36 is present in the current dataset!
# SEMA3A is present in the current dataset!
# AKAP9 is present in the current dataset!
# KRIT1 is present in the current dataset!
# PEX1 is present in the current dataset!
# COL1A2 is present in the current dataset!
# ASNS is present in the current dataset!
# TRRAP is present in the current dataset!
# AP4M1 is present in the current dataset!
# STAG3 is present in the current dataset!
# SLC26A5 is present in the current dataset!
# RELN is present in the current dataset!
# SLC26A4 is present in the current dataset!
# DLD is present in the current dataset!
# FOXP2 is present in the current dataset!
# CFTR is present in the current dataset!
# POT1 is present in the current dataset!
# PAX4 is present in the current dataset!
# IMPDH1 is present in the current dataset!
# OPN1SW is present in the current dataset!
# FLNC is present in the current dataset!
# ATP6V0A4 is present in the current dataset!
# BRAF is present in the current dataset!
# PRSS1 is present in the current dataset!
# CLCN1 is present in the current dataset!
# NOBOX is present in the current dataset!
# CNTNAP2 is present in the current dataset!
# EZH2 is present in the current dataset!
# KCNH2 is present in the current dataset!
# ASB10 is present in the current dataset!
# PRKAG2 is present in the current dataset!
# KMT2C is present in the current dataset!
# XRCC2 is present in the current dataset!
# DPP6 is present in the current dataset!
# SHH is present in the current dataset!
# LMBR1 is present in the current dataset!
# MNX1 is present in the current dataset!
# CLN8 is present in the current dataset!
# ARHGEF10 is present in the current dataset!
# MCPH1 is present in the current dataset!
# RP1L1 is present in the current dataset!
# GATA4 is present in the current dataset!
# MSR1 is present in the current dataset!
# NAT1 is present in the current dataset!
# LPL is present in the current dataset!
# NEFL is present in the current dataset!
# ESCO2 is present in the current dataset!
# WRN is present in the current dataset!
# STAR is present in the current dataset!
# FGFR1 is present in the current dataset!
# ANK1 is present in the current dataset!
# KAT6A is present in the current dataset!
# IKBKB is present in the current dataset!
# SLC20A2 is present in the current dataset!
# HGSNAT is present in the current dataset!
# PRKDC is present in the current dataset!
# RP1 is present in the current dataset!
# CHD7 is present in the current dataset!
# TTPA is present in the current dataset!
# CYP7B1 is present in the current dataset!
# EYA1 is present in the current dataset!
# GDAP1 is present in the current dataset!
# PEX2 is present in the current dataset!
# CNGB3 is present in the current dataset!
# NBN is present in the current dataset!
# OTUD6B is present in the current dataset!
# TMEM67 is present in the current dataset!
# PTDSS1 is present in the current dataset!
# VPS13B is present in the current dataset!
# RRM2B is present in the current dataset!
# ZFPM2 is present in the current dataset!
# TRPS1 is present in the current dataset!
# RAD21 is present in the current dataset!
# EXT1 is present in the current dataset!
# NDUFB9 is present in the current dataset!
# KCNQ3 is present in the current dataset!
# KCNK9 is present in the current dataset!
# CYP11B1 is present in the current dataset!
# PUF60 is present in the current dataset!
# PLEC is present in the current dataset!
# DGAT1 is present in the current dataset!
# SLC52A2 is present in the current dataset!
# RECQL4 is present in the current dataset!
# DOCK8 is present in the current dataset!
# SMARCA2 is present in the current dataset!
# KCNV2 is present in the current dataset!
# JAK2 is present in the current dataset!
# GLDC is present in the current dataset!
# TYRP1 is present in the current dataset!
# MPDZ is present in the current dataset!
# FREM1 is present in the current dataset!
# CDKN2A is present in the current dataset!
# TEK is present in the current dataset!
# DDX58 is present in the current dataset!
# APTX is present in the current dataset!
# DNAI1 is present in the current dataset!
# GALT is present in the current dataset!
# VCP is present in the current dataset!
# PIGO is present in the current dataset!
# GBA2 is present in the current dataset!
# GNE is present in the current dataset!
# GRHPR is present in the current dataset!
# VPS13A is present in the current dataset!
# FHL1 is present in the current dataset!
# HNRNPK is present in the current dataset!
# NTRK2 is present in the current dataset!
# AUH is present in the current dataset!
# ROR2 is present in the current dataset!
# SPTLC1 is present in the current dataset!
# BICD2 is present in the current dataset!
# FANCC is present in the current dataset!
# PTCH1 is present in the current dataset!
# XPA is present in the current dataset!
# TGFBR1 is present in the current dataset!
# ALDOB is present in the current dataset!
# FKTN is present in the current dataset!
# FRRS1L is present in the current dataset!
# TNC is present in the current dataset!
# TRIM32 is present in the current dataset!
# CDK5RAP2 is present in the current dataset!
# C5 is present in the current dataset!
# CRB2 is present in the current dataset!
# NR5A1 is present in the current dataset!
# LMX1B is present in the current dataset!
# STXBP1 is present in the current dataset!
# ENG is present in the current dataset!
# DNM1 is present in the current dataset!
# COQ4 is present in the current dataset!
# SLC27A4 is present in the current dataset!
# GLE1 is present in the current dataset!
# SPTAN1 is present in the current dataset!
# WDR34 is present in the current dataset!
# TOR1A is present in the current dataset!
# ASS1 is present in the current dataset!
# ABL1 is present in the current dataset!
# POMT1 is present in the current dataset!
# SETX is present in the current dataset!
# TSC1 is present in the current dataset!
# CEL is present in the current dataset!
# SURF1 is present in the current dataset!
# DBH is present in the current dataset!
# COL5A1 is present in the current dataset!
# MRPS2 is present in the current dataset!
# SOHLH1 is present in the current dataset!
# KCNT1 is present in the current dataset!
# INPP5E is present in the current dataset!
# NOTCH1 is present in the current dataset!
# AGPAT2 is present in the current dataset!
# EHMT1 is present in the current dataset!
# TUBB8 is present in the current dataset!
# ZMYND11 is present in the current dataset!
# GATA3 is present in the current dataset!
# DHTKD1 is present in the current dataset!
# OPTN is present in the current dataset!
# PHYH is present in the current dataset!
# CUBN is present in the current dataset!
# VIM is present in the current dataset!
# CACNB2 is present in the current dataset!
# ARMC4 is present in the current dataset!
# WAC is present in the current dataset!
# ZEB1 is present in the current dataset!
# RET is present in the current dataset!
# GDF2 is present in the current dataset!
# ERCC6 is present in the current dataset!
# PRKG1 is present in the current dataset!
# MBL2 is present in the current dataset!
# PCDH15 is present in the current dataset!
# EGR2 is present in the current dataset!
# CTNNA3 is present in the current dataset!
# MYPN is present in the current dataset!
# SLC29A3 is present in the current dataset!
# CDH23 is present in the current dataset!
# CHST3 is present in the current dataset!
# ASCC1 is present in the current dataset!
# MRPS16 is present in the current dataset!
# VCL is present in the current dataset!
# ADK is present in the current dataset!
# KAT6B is present in the current dataset!
# SFTPA2 is present in the current dataset!
# ANXA11 is present in the current dataset!
# CDHR1 is present in the current dataset!
# LDB3 is present in the current dataset!
# BMPR1A is present in the current dataset!
# GLUD1 is present in the current dataset!
# PTEN is present in the current dataset!
# ACTA2 is present in the current dataset!
# SLC16A12 is present in the current dataset!
# KIF11 is present in the current dataset!
# CYP26C1 is present in the current dataset!
# LGI1 is present in the current dataset!
# ENTPD1 is present in the current dataset!
# HOGA1 is present in the current dataset!
# HPS1 is present in the current dataset!
# ABCC2 is present in the current dataset!
# PAX2 is present in the current dataset!
# FGF8 is present in the current dataset!
# PITX3 is present in the current dataset!
# NFKB2 is present in the current dataset!
# SUFU is present in the current dataset!
# COL17A1 is present in the current dataset!
# SMC3 is present in the current dataset!
# RBM20 is present in the current dataset!
# SHOC2 is present in the current dataset!
# TCF4 is present in the current dataset!
# KCNK18 is present in the current dataset!
# NANOS1 is present in the current dataset!
# BAG3 is present in the current dataset!
# FGFR2 is present in the current dataset!
# OAT is present in the current dataset!
# ECHS1 is present in the current dataset!
# HRAS is present in the current dataset!
# SLC25A22 is present in the current dataset!
# TNNI2 is present in the current dataset!
# IGF2 is present in the current dataset!
# INS is present in the current dataset!
# TH is present in the current dataset!
# KCNQ1 is present in the current dataset!
# CDKN1C is present in the current dataset!
# HBB is present in the current dataset!
# SMPD1 is present in the current dataset!
# TPP1 is present in the current dataset!
# SBF2 is present in the current dataset!
# KCNJ11 is present in the current dataset!
# ABCC8 is present in the current dataset!
# OTOG is present in the current dataset!
# KCNC1 is present in the current dataset!
# CSRP3 is present in the current dataset!
# SLC6A5 is present in the current dataset!
# ANO5 is present in the current dataset!
# FANCF is present in the current dataset!
# ANO3 is present in the current dataset!
# BDNF is present in the current dataset!
# PAX6 is present in the current dataset!
# WT1 is present in the current dataset!
# PDX1 is present in the current dataset!
# RAG1 is present in the current dataset!
# RAG2 is present in the current dataset!
# EXT2 is present in the current dataset!
# PEX16 is present in the current dataset!
# CREB3L1 is present in the current dataset!
# MYBPC3 is present in the current dataset!
# SLC39A13 is present in the current dataset!
# SERPING1 is present in the current dataset!
# CTNND1 is present in the current dataset!
# FAM111B is present in the current dataset!
# FAM111A is present in the current dataset!
# TMEM216 is present in the current dataset!
# BEST1 is present in the current dataset!
# ROM1 is present in the current dataset!
# GANAB is present in the current dataset!
# SLC22A12 is present in the current dataset!
# PYGM is present in the current dataset!
# MEN1 is present in the current dataset!
# PACS1 is present in the current dataset!
# CLCF1 is present in the current dataset!
# CABP2 is present in the current dataset!
# NDUFV1 is present in the current dataset!
# UNC93B1 is present in the current dataset!
# LRP5 is present in the current dataset!
# CPT1A is present in the current dataset!
# IGHMBP2 is present in the current dataset!
# SHANK2 is present in the current dataset!
# DHCR7 is present in the current dataset!
# MYO7A is present in the current dataset!
# TENM4 is present in the current dataset!
# FZD4 is present in the current dataset!
# TYR is present in the current dataset!
# MTMR2 is present in the current dataset!
# TRPC6 is present in the current dataset!
# YAP1 is present in the current dataset!
# ACAT1 is present in the current dataset!
# ATM is present in the current dataset!
# EXPH5 is present in the current dataset!
# CRYAB is present in the current dataset!
# SDHD is present in the current dataset!
# PTS is present in the current dataset!
# APOA5 is present in the current dataset!
# APOC3 is present in the current dataset!
# APOA1 is present in the current dataset!
# CEP164 is present in the current dataset!
# KMT2A is present in the current dataset!
# CBL is present in the current dataset!
# C1QTNF5 is present in the current dataset!
# MFRP is present in the current dataset!
# GRIK4 is present in the current dataset!
# ROBO3 is present in the current dataset!
# CDON is present in the current dataset!
# KCNJ5 is present in the current dataset!
# WNK1 is present in the current dataset!
# CACNA1C is present in the current dataset!
# KCNA1 is present in the current dataset!
# KCNA5 is present in the current dataset!
# VWF is present in the current dataset!
# TNFRSF1A is present in the current dataset!
# CD27 is present in the current dataset!
# VAMP1 is present in the current dataset!
# ATN1 is present in the current dataset!
# C1R is present in the current dataset!
# GDF3 is present in the current dataset!
# AICDA is present in the current dataset!
# MFAP5 is present in the current dataset!
# A2ML1 is present in the current dataset!
# LRP6 is present in the current dataset!
# CDKN1B is present in the current dataset!
# GRIN2B is present in the current dataset!
# SLCO1B1 is present in the current dataset!
# PYROXD1 is present in the current dataset!
# GYS2 is present in the current dataset!
# ABCC9 is present in the current dataset!
# SOX5 is present in the current dataset!
# KRAS is present in the current dataset!
# PTHLH is present in the current dataset!
# DDX11 is present in the current dataset!
# DNM1L is present in the current dataset!
# PKP2 is present in the current dataset!
# KIF21A is present in the current dataset!
# LRRK2 is present in the current dataset!
# IRAK4 is present in the current dataset!
# ARID2 is present in the current dataset!
# COL2A1 is present in the current dataset!
# KMT2D is present in the current dataset!
# TUBA1A is present in the current dataset!
# SCN8A is present in the current dataset!
# ACVRL1 is present in the current dataset!
# KRT6B is present in the current dataset!
# KRT6C is present in the current dataset!
# KRT5 is present in the current dataset!
# KRT74 is present in the current dataset!
# KRT2 is present in the current dataset!
# KRT1 is present in the current dataset!
# KRT4 is present in the current dataset!
# AAAS is present in the current dataset!
# HOXC13 is present in the current dataset!
# RDH5 is present in the current dataset!
# SUOX is present in the current dataset!
# RPS26 is present in the current dataset!
# SLC39A5 is present in the current dataset!
# STAC3 is present in the current dataset!
# KIF5A is present in the current dataset!
# TBK1 is present in the current dataset!
# GNS is present in the current dataset!
# LEMD3 is present in the current dataset!
# LYZ is present in the current dataset!
# BBS10 is present in the current dataset!
# SYT1 is present in the current dataset!
# OTOGL is present in the current dataset!
# CEP290 is present in the current dataset!
# POC1B is present in the current dataset!
# CRADD is present in the current dataset!
# PAH is present in the current dataset!
# ASCL1 is present in the current dataset!
# POLR3B is present in the current dataset!
# UBE3B is present in the current dataset!
# MMAB is present in the current dataset!
# MVK is present in the current dataset!
# TRPV4 is present in the current dataset!
# ATP2A2 is present in the current dataset!
# MYL2 is present in the current dataset!
# PTPN11 is present in the current dataset!
# TBX5 is present in the current dataset!
# TBX3 is present in the current dataset!
# MED13L is present in the current dataset!
# CIT is present in the current dataset!
# ACADS is present in the current dataset!
# HNF1A is present in the current dataset!
# HPD is present in the current dataset!
# TCTN2 is present in the current dataset!
# ATP6V0A2 is present in the current dataset!
# P2RX2 is present in the current dataset!
# GJA3 is present in the current dataset!
# GJB2 is present in the current dataset!
# FGF9 is present in the current dataset!
# SGCG is present in the current dataset!
# SACS is present in the current dataset!
# CENPJ is present in the current dataset!
# BRCA2 is present in the current dataset!
# SMAD9 is present in the current dataset!
# FREM2 is present in the current dataset!
# COG6 is present in the current dataset!
# SLC25A15 is present in the current dataset!
# RB1 is present in the current dataset!
# RNASEH2B is present in the current dataset!
# ATP7B is present in the current dataset!
# ALG11 is present in the current dataset!
# CLN5 is present in the current dataset!
# EDNRB is present in the current dataset!
# SLITRK1 is present in the current dataset!
# ZIC2 is present in the current dataset!
# PCCA is present in the current dataset!
# NALCN is present in the current dataset!
# SLC10A2 is present in the current dataset!
# LIG4 is present in the current dataset!
# COL4A1 is present in the current dataset!
# COL4A2 is present in the current dataset!
# F7 is present in the current dataset!
# ANG is present in the current dataset!
# RPGRIP1 is present in the current dataset!
# CHD8 is present in the current dataset!
# MYH6 is present in the current dataset!
# MYH7 is present in the current dataset!
# TINF2 is present in the current dataset!
# TGM1 is present in the current dataset!
# FOXG1 is present in the current dataset!
# PRKD1 is present in the current dataset!
# COCH is present in the current dataset!
# NFKBIA is present in the current dataset!
# NKX2-1 is present in the current dataset!
# FANCM is present in the current dataset!
# ATL1 is present in the current dataset!
# BMP4 is present in the current dataset!
# GCH1 is present in the current dataset!
# OTX2 is present in the current dataset!
# KIAA0586 is present in the current dataset!
# SIX6 is present in the current dataset!
# SIX1 is present in the current dataset!
# SYNE2 is present in the current dataset!
# ESR2 is present in the current dataset!
# MTHFD1 is present in the current dataset!
# SPTB is present in the current dataset!
# RDH12 is present in the current dataset!
# ZFYVE26 is present in the current dataset!
# ACTN1 is present in the current dataset!
# PSEN1 is present in the current dataset!
# ALDH6A1 is present in the current dataset!
# NPC2 is present in the current dataset!
# MLH3 is present in the current dataset!
# NEK9 is present in the current dataset!
# FLVCR2 is present in the current dataset!
# TGFB3 is present in the current dataset!
# IRF2BPL is present in the current dataset!
# POMT2 is present in the current dataset!
# SPTLC2 is present in the current dataset!
# TSHR is present in the current dataset!
# GALC is present in the current dataset!
# CALM1 is present in the current dataset!
# FBLN5 is present in the current dataset!
# ATXN3 is present in the current dataset!
# SERPINA1 is present in the current dataset!
# DICER1 is present in the current dataset!
# BCL11B is present in the current dataset!
# YY1 is present in the current dataset!
# DYNC1H1 is present in the current dataset!
# TECPR2 is present in the current dataset!
# INF2 is present in the current dataset!
# NIPA1 is present in the current dataset!
# MAGEL2 is present in the current dataset!
# UBE3A is present in the current dataset!
# GABRB3 is present in the current dataset!
# SLC12A6 is present in the current dataset!
# ACTC1 is present in the current dataset!
# MEIS2 is present in the current dataset!
# SPRED1 is present in the current dataset!
# IVD is present in the current dataset!
# RAD51 is present in the current dataset!
# DLL4 is present in the current dataset!
# CAPN3 is present in the current dataset!
# TUBGCP4 is present in the current dataset!
# STRC is present in the current dataset!
# SPG11 is present in the current dataset!
# DUOX2 is present in the current dataset!
# SLC24A5 is present in the current dataset!
# FBN1 is present in the current dataset!
# CEP152 is present in the current dataset!
# MYO5A is present in the current dataset!
# RAB27A is present in the current dataset!
# TCF12 is present in the current dataset!
# VPS13C is present in the current dataset!
# PPIB is present in the current dataset!
# KBTBD13 is present in the current dataset!
# MAP2K1 is present in the current dataset!
# SMAD6 is present in the current dataset!
# SMAD3 is present in the current dataset!
# AAGAB is present in the current dataset!
# CLN6 is present in the current dataset!
# NR2E3 is present in the current dataset!
# HEXA is present in the current dataset!
# HCN4 is present in the current dataset!
# STRA6 is present in the current dataset!
# SIN3A is present in the current dataset!
# PSTPIP1 is present in the current dataset!
# FAH is present in the current dataset!
# AP3B2 is present in the current dataset!
# ALPK3 is present in the current dataset!
# AGBL1 is present in the current dataset!
# ACAN is present in the current dataset!
# RLBP1 is present in the current dataset!
# POLG is present in the current dataset!
# KIF7 is present in the current dataset!
# IDH2 is present in the current dataset!
# BLM is present in the current dataset!
# CHD2 is present in the current dataset!
# NR2F2 is present in the current dataset!
# NPRL3 is present in the current dataset!
# HBA2 is present in the current dataset!
# PIGQ is present in the current dataset!
# CCDC78 is present in the current dataset!
# CACNA1H is present in the current dataset!
# TELO2 is present in the current dataset!
# NTHL1 is present in the current dataset!
# TSC2 is present in the current dataset!
# PKD1 is present in the current dataset!
# THOC6 is present in the current dataset!
# MEFV is present in the current dataset!
# CREBBP is present in the current dataset!
# ALG1 is present in the current dataset!
# PMM2 is present in the current dataset!
# GRIN2A is present in the current dataset!
# MYH11 is present in the current dataset!
# ABCC6 is present in the current dataset!
# CRYM is present in the current dataset!
# EARS2 is present in the current dataset!
# PALB2 is present in the current dataset!
# CLN3 is present in the current dataset!
# KIF22 is present in the current dataset!
# PRRT2 is present in the current dataset!
# TBX6 is present in the current dataset!
# SRCAP is present in the current dataset!
# STX1B is present in the current dataset!
# FUS is present in the current dataset!
# ARMC5 is present in the current dataset!
# VPS35 is present in the current dataset!
# PHKB is present in the current dataset!
# CYLD is present in the current dataset!
# SALL1 is present in the current dataset!
# RPGRIP1L is present in the current dataset!
# GNAO1 is present in the current dataset!
# BBS2 is present in the current dataset!
# SLC12A3 is present in the current dataset!
# TK2 is present in the current dataset!
# HSF4 is present in the current dataset!
# CTCF is present in the current dataset!
# LCAT is present in the current dataset!
# PRMT7 is present in the current dataset!
# CDH1 is present in the current dataset!
# COG4 is present in the current dataset!
# TAT is present in the current dataset!
# DHODH is present in the current dataset!
# WWOX is present in the current dataset!
# MAF is present in the current dataset!
# GAN is present in the current dataset!
# IRF8 is present in the current dataset!
# FOXC2 is present in the current dataset!
# ZNF469 is present in the current dataset!
# CTU2 is present in the current dataset!
# PIEZO1 is present in the current dataset!
# CDH15 is present in the current dataset!
# ANKRD11 is present in the current dataset!
# SPG7 is present in the current dataset!
# FANCA is present in the current dataset!
# PRPF8 is present in the current dataset!
# WDR81 is present in the current dataset!
# SERPINF1 is present in the current dataset!
# PAFAH1B1 is present in the current dataset!
# ASPA is present in the current dataset!
# CTNS is present in the current dataset!
# CHRNE is present in the current dataset!
# KIF1C is present in the current dataset!
# AIPL1 is present in the current dataset!
# ACADVL is present in the current dataset!
# TP53 is present in the current dataset!
# GUCY2D is present in the current dataset!
# ALOX12B is present in the current dataset!
# CTC1 is present in the current dataset!
# MYH8 is present in the current dataset!
# MYH2 is present in the current dataset!
# MYH3 is present in the current dataset!
# SCO1 is present in the current dataset!
# PMP22 is present in the current dataset!
# FLCN is present in the current dataset!
# RAI1 is present in the current dataset!
# SMS is present in the current dataset!
# MYO15A is present in the current dataset!
# ALDH3A2 is present in the current dataset!
# SLC46A1 is present in the current dataset!
# CRYBA1 is present in the current dataset!
# RNF135 is present in the current dataset!
# NF1 is present in the current dataset!
# RAD51D is present in the current dataset!
# PEX12 is present in the current dataset!
# HNF1B is present in the current dataset!
# GPR179 is present in the current dataset!
# THRA is present in the current dataset!
# SMARCE1 is present in the current dataset!
# KRT10 is present in the current dataset!
# KRT9 is present in the current dataset!
# KRT14 is present in the current dataset!
# KRT16 is present in the current dataset!
# STAT3 is present in the current dataset!
# NAGLU is present in the current dataset!
# TUBG1 is present in the current dataset!
# WNK4 is present in the current dataset!
# G6PC is present in the current dataset!
# BRCA1 is present in the current dataset!
# UBTF is present in the current dataset!
# SLC4A1 is present in the current dataset!
# GRN is present in the current dataset!
# FZD2 is present in the current dataset!
# EFTUD2 is present in the current dataset!
# GFAP is present in the current dataset!
# KANSL1 is present in the current dataset!
# ITGB3 is present in the current dataset!
# DLX3 is present in the current dataset!
# SGCA is present in the current dataset!
# COL1A1 is present in the current dataset!
# CACNA1G is present in the current dataset!
# MKS1 is present in the current dataset!
# MPO is present in the current dataset!
# RAD51C is present in the current dataset!
# CLTC is present in the current dataset!
# CA4 is present in the current dataset!
# PPM1D is present in the current dataset!
# TBX4 is present in the current dataset!
# BRIP1 is present in the current dataset!
# TLK2 is present in the current dataset!
# SCN4A is present in the current dataset!
# POLG2 is present in the current dataset!
# AXIN2 is present in the current dataset!
# BPTF is present in the current dataset!
# PRKAR1A is present in the current dataset!
# SOX9 is present in the current dataset!
# DNAI2 is present in the current dataset!
# PCNT is present in the current dataset!
# MRPS7 is present in the current dataset!
# SLC25A19 is present in the current dataset!
# TSEN54 is present in the current dataset!
# GALK1 is present in the current dataset!
# UNC13D is present in the current dataset!
# CANT1 is present in the current dataset!
# CCDC40 is present in the current dataset!
# GAA is present in the current dataset!
# CARD14 is present in the current dataset!
# SGSH is present in the current dataset!
# RNF213 is present in the current dataset!
# ACTG1 is present in the current dataset!
# PYCR1 is present in the current dataset!
# SMCHD1 is present in the current dataset!
# TGIF1 is present in the current dataset!
# NDUFV2 is present in the current dataset!
# PIEZO2 is present in the current dataset!
# GNAL is present in the current dataset!
# GREB1L is present in the current dataset!
# MIB1 is present in the current dataset!
# GATA6 is present in the current dataset!
# DSC2 is present in the current dataset!
# DSG1 is present in the current dataset!
# DSG4 is present in the current dataset!
# DSG2 is present in the current dataset!
# TTR is present in the current dataset!
# ASXL3 is present in the current dataset!
# DTNA is present in the current dataset!
# SETBP1 is present in the current dataset!
# EPG5 is present in the current dataset!
# LOXHD1 is present in the current dataset!
# MYO5B is present in the current dataset!
# SMAD4 is present in the current dataset!
# ATP8B1 is present in the current dataset!
# NEDD4L is present in the current dataset!
# CCBE1 is present in the current dataset!
# MC4R is present in the current dataset!
# TSHZ1 is present in the current dataset!
# ELANE is present in the current dataset!
# STK11 is present in the current dataset!
# GAMT is present in the current dataset!
# GNA11 is present in the current dataset!
# GIPC3 is present in the current dataset!
# RAX2 is present in the current dataset!
# MAP2K2 is present in the current dataset!
# STXBP2 is present in the current dataset!
# ADAMTS10 is present in the current dataset!
# DNMT1 is present in the current dataset!
# DNM2 is present in the current dataset!
# SMARCA4 is present in the current dataset!
# LDLR is present in the current dataset!
# EPOR is present in the current dataset!
# PRKCSH is present in the current dataset!
# MAN2B1 is present in the current dataset!
# RNASEH2A is present in the current dataset!
# KLF1 is present in the current dataset!
# GCDH is present in the current dataset!
# NFIX is present in the current dataset!
# TRMT1 is present in the current dataset!
# NACC1 is present in the current dataset!
# CACNA1A is present in the current dataset!
# NOTCH3 is present in the current dataset!
# CALR3 is present in the current dataset!
# JAK3 is present in the current dataset!
# IL12RB1 is present in the current dataset!
# PIK3R2 is present in the current dataset!
# COMP is present in the current dataset!
# SLC7A9 is present in the current dataset!
# CEBPA is present in the current dataset!
# GPI is present in the current dataset!
# SCN1B is present in the current dataset!
# KMT2B is present in the current dataset!
# NPHS1 is present in the current dataset!
# WDR62 is present in the current dataset!
# RYR1 is present in the current dataset!
# ACTN4 is present in the current dataset!
# PRX is present in the current dataset!
# LTBP4 is present in the current dataset!
# RPS19 is present in the current dataset!
# ATP1A3 is present in the current dataset!
# ERF is present in the current dataset!
# CIC is present in the current dataset!
# LIPE is present in the current dataset!
# KCNN4 is present in the current dataset!
# CEACAM16 is present in the current dataset!
# BCAM is present in the current dataset!
# APOE is present in the current dataset!
# ERCC2 is present in the current dataset!
# RTN2 is present in the current dataset!
# SIX5 is present in the current dataset!
# FKRP is present in the current dataset!
# KPTN is present in the current dataset!
# CCDC114 is present in the current dataset!
# FUT1 is present in the current dataset!
# TRPM4 is present in the current dataset!
# PNKP is present in the current dataset!
# MYH14 is present in the current dataset!
# KCNC3 is present in the current dataset!
# POLD1 is present in the current dataset!
# ETFB is present in the current dataset!
# PPP2R1A is present in the current dataset!
# NLRP12 is present in the current dataset!
# PRPF31 is present in the current dataset!
# TSEN34 is present in the current dataset!
# TNNI3 is present in the current dataset!
# CSNK2A1 is present in the current dataset!
# PDYN is present in the current dataset!
# TGM6 is present in the current dataset!
# SNRPB is present in the current dataset!
# SLC4A11 is present in the current dataset!
# PANK2 is present in the current dataset!
# PROKR2 is present in the current dataset!
# PLCB4 is present in the current dataset!
# JAG1 is present in the current dataset!
# SEC23B is present in the current dataset!
# VSX1 is present in the current dataset!
# ABHD12 is present in the current dataset!
# ASXL1 is present in the current dataset!
# GSS is present in the current dataset!
# GDF5 is present in the current dataset!
# EPB41L1 is present in the current dataset!
# JPH2 is present in the current dataset!
# HNF4A is present in the current dataset!
# ADA is present in the current dataset!
# PIGT is present in the current dataset!
# ARFGEF2 is present in the current dataset!
# ADNP is present in the current dataset!
# DPM1 is present in the current dataset!
# SALL4 is present in the current dataset!
# CYP24A1 is present in the current dataset!
# GNAS is present in the current dataset!
# EDN3 is present in the current dataset!
# GATA5 is present in the current dataset!
# COL9A3 is present in the current dataset!
# SLC17A9 is present in the current dataset!
# CHRNA4 is present in the current dataset!
# KCNQ2 is present in the current dataset!
# EEF1A2 is present in the current dataset!
# RTEL1 is present in the current dataset!
# DNAJC5 is present in the current dataset!
# SOD1 is present in the current dataset!
# SYNJ1 is present in the current dataset!
# SON is present in the current dataset!
# KCNE2 is present in the current dataset!
# KCNE1 is present in the current dataset!
# RUNX1 is present in the current dataset!
# DYRK1A is present in the current dataset!
# TMPRSS3 is present in the current dataset!
# RSPH1 is present in the current dataset!
# CBS is present in the current dataset!
# SIK1 is present in the current dataset!
# CSTB is present in the current dataset!
# AIRE is present in the current dataset!
# COL18A1 is present in the current dataset!
# COL6A1 is present in the current dataset!
# COL6A2 is present in the current dataset!
# TBX1 is present in the current dataset!
# TXNRD2 is present in the current dataset!
# TANGO2 is present in the current dataset!
# SCARF2 is present in the current dataset!
# SERPIND1 is present in the current dataset!
# LZTR1 is present in the current dataset!
# SMARCB1 is present in the current dataset!
# SPECC1L is present in the current dataset!
# UPB1 is present in the current dataset!
# CRYBB2 is present in the current dataset!
# CHEK2 is present in the current dataset!
# NEFH is present in the current dataset!
# NF2 is present in the current dataset!
# MORC2 is present in the current dataset!
# DEPDC5 is present in the current dataset!
# TIMP3 is present in the current dataset!
# MYH9 is present in the current dataset!
# TMPRSS6 is present in the current dataset!
# SOX10 is present in the current dataset!
# PLA2G6 is present in the current dataset!
# ADSL is present in the current dataset!
# EP300 is present in the current dataset!
# CYP2D6 is present in the current dataset!
# TCF20 is present in the current dataset!
# MLC1 is present in the current dataset!
# TUBGCP6 is present in the current dataset!
# SCO2 is present in the current dataset!
# TYMP is present in the current dataset!
# ARSA is present in the current dataset!
# SHANK3 is present in the current dataset!
# STS is present in the current dataset!
# GPR143 is present in the current dataset!
# CLCN4 is present in the current dataset!
# AMELX is present in the current dataset!
# MSL3 is present in the current dataset!
# TRAPPC2 is present in the current dataset!
# OFD1 is present in the current dataset!
# FANCB is present in the current dataset!
# NHS is present in the current dataset!
# CDKL5 is present in the current dataset!
# PHKA2 is present in the current dataset!
# PDHA1 is present in the current dataset!
# RPS6KA3 is present in the current dataset!
# CNKSR2 is present in the current dataset!
# SMPX is present in the current dataset!
# MBTPS2 is present in the current dataset!
# PHEX is present in the current dataset!
# EIF2S3 is present in the current dataset!
# ARX is present in the current dataset!
# IL1RAPL1 is present in the current dataset!
# NR0B1 is present in the current dataset!
# DMD is present in the current dataset!
# CYBB is present in the current dataset!
# RPGR is present in the current dataset!
# OTC is present in the current dataset!
# BCOR is present in the current dataset!
# USP9X is present in the current dataset!
# DDX3X is present in the current dataset!
# NYX is present in the current dataset!
# CASK is present in the current dataset!
# KDM6A is present in the current dataset!
# ZNF674 is present in the current dataset!
# RP2 is present in the current dataset!
# RBM10 is present in the current dataset!
# FTSJ1 is present in the current dataset!
# WAS is present in the current dataset!
# PQBP1 is present in the current dataset!
# WDR45 is present in the current dataset!
# CACNA1F is present in the current dataset!
# CCDC22 is present in the current dataset!
# FOXP3 is present in the current dataset!
# CLCN5 is present in the current dataset!
# SHROOM4 is present in the current dataset!
# BMP15 is present in the current dataset!
# KDM5C is present in the current dataset!
# IQSEC2 is present in the current dataset!
# HUWE1 is present in the current dataset!
# PHF8 is present in the current dataset!
# FGD1 is present in the current dataset!
# ARHGEF9 is present in the current dataset!
# AMER1 is present in the current dataset!
# MSN is present in the current dataset!
# AR is present in the current dataset!
# OPHN1 is present in the current dataset!
# EFNB1 is present in the current dataset!
# EDA is present in the current dataset!
# TEX11 is present in the current dataset!
# IL2RG is present in the current dataset!
# MED12 is present in the current dataset!
# NONO is present in the current dataset!
# TAF1 is present in the current dataset!
# HDAC8 is present in the current dataset!
# PHKA1 is present in the current dataset!
# ZDHHC15 is present in the current dataset!
# ATRX is present in the current dataset!
# ATP7A is present in the current dataset!
# ZNF711 is present in the current dataset!
# CHM is present in the current dataset!
# PCDH19 is present in the current dataset!
# SRPX2 is present in the current dataset!
# BTK is present in the current dataset!
# GLA is present in the current dataset!
# MID2 is present in the current dataset!
# COL4A6 is present in the current dataset!
# COL4A5 is present in the current dataset!
# DCX is present in the current dataset!
# ALG13 is present in the current dataset!
# AGTR2 is present in the current dataset!
# UPF3B is present in the current dataset!
# LAMP2 is present in the current dataset!
# CUL4B is present in the current dataset!
# GRIA3 is present in the current dataset!
# THOC2 is present in the current dataset!
# OCRL is present in the current dataset!
# ZDHHC9 is present in the current dataset!
# AIFM1 is present in the current dataset!
# IGSF1 is present in the current dataset!
# GPC3 is present in the current dataset!
# PHF6 is present in the current dataset!
# HPRT1 is present in the current dataset!
# SLC9A6 is present in the current dataset!
# CD40LG is present in the current dataset!
# GPR101 is present in the current dataset!
# F9 is present in the current dataset!
# FMR1 is present in the current dataset!
# AFF2 is present in the current dataset!
# IDS is present in the current dataset!
# MAMLD1 is present in the current dataset!
# MTM1 is present in the current dataset!
# BGN is present in the current dataset!
# ATP2B3 is present in the current dataset!
# SLC6A8 is present in the current dataset!
# ABCD1 is present in the current dataset!
# L1CAM is present in the current dataset!
# AVPR2 is present in the current dataset!
# NAA10 is present in the current dataset!
# HCFC1 is present in the current dataset!
# MECP2 is present in the current dataset!
# OPN1LW is present in the current dataset!
# FLNA is present in the current dataset!
# EMD is present in the current dataset!
# ATP6AP1 is present in the current dataset!
# LAGE3 is present in the current dataset!
# G6PD is present in the current dataset!
# DKC1 is present in the current dataset!
# F8 is present in the current dataset!
# Total percentage of OMIM genes in dataset: 4.01%

# %% [markdown]
# Now to do: map these omim genes and look up their AUC.
# Map the infever genes to own genes [Infevers](https://infevers.umai-montpellier.fr/web/)
#
# __Priority share research proposal for approval by Joeri and Shuang__
#
# # This notebook has ended, please see detailed_data_visualization.ipynb
